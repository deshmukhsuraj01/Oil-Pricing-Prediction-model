# %% [markdown]
# # Dataset: macrotrends crude oil csv

# %%
# Importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('macrotrends crude oil.csv') # Loading Dataset

# %% [markdown]
# # Visualization and Data Preprocessing

# %%
df.head(10)
# Out:
#          date   value
# 0  07-02-2011   86.30
# 1  08-02-2011   85.85
# 2  09-02-2011   85.59
# 3  10-02-2011   85.44
# 4  11-02-2011   84.39
# 5  14-02-2011   83.66
# 6  15-02-2011   83.13
# 7  16-02-2011   83.80
# 8  17-02-2011   85.05
# 9  18-02-2011   85.03

# %%
df.shape
# Out:
# (3313, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3313 entries, 0 to 3312
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    3313 non-null   object
#  1    value  3292 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 51.9+ KB

# %%
df.isnull().sum()
# Out:
# date       0
#  value    21
# dtype: int64

# %%
df=df.dropna()

# %%
df.isnull().sum()
# Out:
# date      0
#  value    0
# dtype: int64

# %%
df.head()
# Out:
#          date   value
# 0  07-02-2011   86.30
# 1  08-02-2011   85.85
# 2  09-02-2011   85.59
# 3  10-02-2011   85.44
# 4  11-02-2011   84.39

# %%
df.columns
# Out:
# Index(['date', ' value'], dtype='object')

# %%
df['date']=pd.to_datetime(df['date'])
# Out:
# C:\Users\marri\AppData\Local\Temp\ipykernel_9924\1213281828.py:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df['date']=pd.to_datetime(df['date'])

# %%
df.rename(columns={' value':'price'},inplace=True)

# %%
df
# Out:
#            date  price
# 0    2011-07-02  86.30
# 1    2011-08-02  85.85
# 2    2011-09-02  85.59
# 3    2011-10-02  85.44
# 4    2011-11-02  84.39
# ...         ...    ...
# 3287 2024-01-30  77.79
# 3288 2024-01-31  75.85
# 3289 2024-01-02  73.82
# 3290 2024-02-02  72.41
# 3291 2024-05-02  72.13
#
# [3292 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3292 entries, 0 to 3291
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    3292 non-null   datetime64[ns]
#  1   price   3292 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 77.2 KB

# %%
df.describe().T
# Out:
#         count       mean        std     min     25%     50%    75%    max
# price  3292.0  71.165593  22.598418  11.258  51.645  70.015  92.44  123.7

# %%
fig, ax = plt.subplots(figsize=(30, 10))
sns.lineplot(data=df,x ="date",y ="price",color = "red",marker = ".")
# Out:
# <Axes: xlabel='date', ylabel='price'>

# %%
import statsmodels.api as smf

# %%
seasonal_ts_add=smf.tsa.seasonal_decompose(df["price"],period=10)
seasonal_ts_add.plot()

# %%
# Histogram
df['price'].hist(figsize=(8,5))
# Out:
# <Axes: >

# %%
# Density Plot
df['price'].plot(kind = 'kde', figsize=(8,5))
# Out:
# <Axes: ylabel='Density'>

# %%
sns.boxplot(data=df['price'])
# Out:
# <Axes: >

# %%
df[df['price']>115]
# Out:
#            date    price
# 2788 2022-04-03  115.680
# 2789 2022-07-03  119.400
# 2790 2022-08-03  123.700
# 2848 2022-05-27  115.070
# 2850 2022-01-06  115.260
# 2851 2022-02-06  116.870
# 2852 2022-03-06  118.870
# 2853 2022-06-06  118.500
# 2854 2022-07-06  119.410
# 2855 2022-08-06  122.110
# 2856 2022-09-06  121.510
# 2857 2022-10-06  120.670
# 2858 2022-06-13  120.930
# 2859 2022-06-14  118.930
# 2860 2022-06-15  115.310
# 2861 2022-06-16  117.122

# %% [markdown]
# **Oil prices were on peak during this period due to decresed inventory of crude oil in second quarter of year & the low inventory was due to Russia ukraine war in first quarter of the year.**

# %%
df[df['price']<20]
# Out:
#            date   price
# 2308 2020-04-15  19.870
# 2311 2020-04-21  11.258
# 2312 2020-04-22  13.780
# 2313 2020-04-23  16.500
# 2314 2020-04-24  16.940
# 2315 2020-04-27  12.780
# 2316 2020-04-28  12.340
# 2317 2020-04-29  15.060
# 2318 2020-04-30  18.840
# 2319 2020-01-05  19.780

# %% [markdown]
# **Oil prices dropped in this period due low demand due to COVID-19.**

# %% [markdown]
# - Major shift

# %%
Price_bef_2015=df['price'][df['date']<'2015-03-01'].mean()
print('Mean Price before 2015=',round(Price_bef_2015,2))
Price_bw_2015_2020=df['price'][(df['date']>'2015-03-01') & (df['date']<'2020-03-01')].mean()
print('Mean Price between 2015 & 2020=',round(Price_bw_2015_2020,2))
dev=(Price_bw_2015_2020/Price_bef_2015)-1
print('%Deviation between price of both periods=',round(dev*100,2),'%')
# Out:
# Mean Price before 2015= 93.36
# Mean Price between 2015 & 2020= 52.91
# %Deviation between price of both periods= -43.33 %

# %% [markdown]
# **Major change between these two periods due to supply factor. In this duration US supply was in boom which reduced oil prices globaly.Boom in supply was due to advancement in drilling technologies & allowing free export of crude oil**

# %% [markdown]
# - Breaking data of 2015 to 2020

# %%
Price_bw_2015_2018=df['price'][(df['date']>'2015-03-01') & (df['date']<'2018-03-01')].mean()
print('Mean Price between 2015 & 2018=',round(Price_bw_2015_2018,2))
Price_bw_2018_2019=df['price'][(df['date']>'2018-03-01') & (df['date']<'2019-03-01')].mean()
print('Mean Price between 2018 & 2019=',round(Price_bw_2018_2019,2))
dev2=(Price_bw_2018_2019/Price_bw_2015_2018)-1
print('%Deviation between price of both periods=',round(dev2*100,2),'%')
# Out:
# Mean Price between 2015 & 2018= 48.39
# Mean Price between 2018 & 2019= 63.73
# %Deviation between price of both periods= 31.71 %

# %% [markdown]
# **Major Increase between these two periods due to decrease in US economy & weak dollar.This increased the demand of oil & in turn increase in price.Weak dollar was due to fiscal stimulus, political crises in europe etc.**

# %%
from pandas.plotting import lag_plot
lag_plot(df['price'])
plt.show()

# %%
#Moving Average
plt.figure(figsize=(14,6))
df.price.plot(label="org")
for i in range(4,13,4):
    df["price"].rolling(i).mean().plot(label=str(i))
plt.legend(loc='best')
plt.show()

# %%
#ACF plots and PACF plots
import statsmodels.graphics.tsaplots as tsa_plots
with plt.rc_context():
    plt.rc("figure", figsize=(14,6))
    tsa_plots.plot_acf(df.price, lags=90)
    plt.show()

# %%
import statsmodels.graphics.tsaplots as tsa_plots
with plt.rc_context():
    plt.rc("figure", figsize=(14,4))
    tsa_plots.plot_pacf(df.price,lags=45)
    plt.show()

# %%
df1 = pd.read_csv('EuropeanBrent.csv') # Loading Dataset

# %%
df1
# Out:
#               Date  Europe Brent Spot Price FOB (Dollars per Barrel)
# 0     May 20, 1987                                             18.63
# 1     May 21, 1987                                             18.45
# 2     May 22, 1987                                             18.55
# 3     May 25, 1987                                             18.60
# 4     May 26, 1987                                             18.63
# ...            ...                                               ...
# 9077  Feb 22, 2023                                             79.55
# 9078  Feb 23, 2023                                             82.08
# 9079  Feb 24, 2023                                             82.31
# 9080  Feb 27, 2023                                             82.31
# 9081           NaN                                               NaN
#
# [9082 rows x 2 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9082 entries, 0 to 9081
# Data columns (total 2 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   Date                                              9081 non-null   object
#  1   Europe Brent Spot Price FOB (Dollars per Barrel)  9081 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 142.0+ KB

# %%
df1.isnull().sum()
# Out:
# Date                                                1
# Europe Brent Spot Price FOB (Dollars per Barrel)    1
# dtype: int64

# %%
df1=df1.dropna()

# %%
df1.isnull().sum()
# Out:
# Date                                                0
# Europe Brent Spot Price FOB (Dollars per Barrel)    0
# dtype: int64

# %%
df1['Date']=pd.to_datetime(df1['Date'])
# Out:
# C:\Users\marri\AppData\Local\Temp\ipykernel_9924\580751001.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Date']=pd.to_datetime(df1['Date'])

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9081 entries, 0 to 9080
# Data columns (total 2 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   Date                                              9081 non-null   datetime64[ns]
#  1   Europe Brent Spot Price FOB (Dollars per Barrel)  9081 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 212.8 KB

# %%
df1.rename(columns={'Europe Brent Spot Price FOB (Dollars per Barrel)':'price'},inplace=True)
df1
# Out:
# C:\Users\marri\AppData\Local\Temp\ipykernel_9924\1450883617.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.rename(columns={'Europe Brent Spot Price FOB (Dollars per Barrel)':'price'},inplace=True)
#            Date  price
# 0    1987-05-20  18.63
# 1    1987-05-21  18.45
# 2    1987-05-22  18.55
# 3    1987-05-25  18.60
# 4    1987-05-26  18.63
# ...         ...    ...
# 9076 2023-02-21  82.14
# 9077 2023-02-22  79.55
# 9078 2023-02-23  82.08
# 9079 2023-02-24  82.31
# 9080 2023-02-27  82.31
#
# [9081 rows x 2 columns]

# %%
fig, ax = plt.subplots(figsize=(30, 10))
sns.lineplot(data=df1,x ="Date",y ="price",color = "red",marker = ".")
# Out:
# <Axes: xlabel='Date', ylabel='price'>

# %%
sns.boxplot(data=df1['price'])
# Out:
# <Axes: >

# %%
Price_bw_2011_2015=df['price'][(df['date']>'2011-02-01') & (df['date']<'2015-03-01')].mean()
print('Mean Price between 2011 & 2015=',round(Price_bw_2011_2015,2))
Price_bw_2015_2020=df['price'][(df['date']>'2015-03-01') & (df['date']<'2020-03-01')].mean()
print('Mean Price between 2015 & 2020=',round(Price_bw_2015_2020,2))
dev=(Price_bw_2015_2020/Price_bw_2011_2015)-1
print('%Deviation between price of both periods=',round(dev*100,2),'%')
# Out:
# Mean Price between 2011 & 2015= 93.33
# Mean Price between 2015 & 2020= 52.91
# %Deviation between price of both periods= -43.31 %

# %% [markdown]
# **Observations same as macrotrends data for period 2011 to 2024, Lets see observation before this period**

# %%
df1[df1['price']>140]
# Out:
#            Date   price
# 5371 2008-07-01  140.67
# 5372 2008-07-02  141.24
# 5373 2008-07-03  143.95
# 5378 2008-07-11  143.68
# 5379 2008-07-14  142.43

# %%
Price_before_2004=df1['price'][df1['Date']<'2004-03-01'].mean()
print('Mean Price before 2004=',round(Price_before_2004,2))
Price_bw_2004_2008=df1['price'][(df1['Date']>'2004-03-01') & (df1['Date']<'2008-08-01')].mean()
print('Mean Price between 2004 & 2008=',round(Price_bw_2004_2008,2))
dev=(Price_bw_2004_2008/Price_before_2004)-1
print('%Deviation between price of both periods=',round(dev*100,2),'%')
# Out:
# Mean Price before 2004= 20.28
# Mean Price between 2004 & 2008= 65.62
# %Deviation between price of both periods= 223.55 %

# %% [markdown]
# From 2004 to 2008 oil prices continued to rise due to rising in demand & not meeting the demand by suppliers. in This period worlds dependency was only on OPECs (organization of petrolium exporting countries). Majorly Due to lack of technology OPECs were not able to meet the demand. Other reasons were political issues which lowered oil production & severe storm which damaged infrastructure & supply of oil in OPEC countries.

# %%
Least_Price_bw_2008_2011=df1['price'][(df1['Date']>'2008-08-01') & (df1['Date']<'2011-02-01')].min()
print('Least_Price_bw_2008_2011=',round(Least_Price_bw_2008_2011,2))
df1[df1['price']==Least_Price_bw_2008_2011]
# Out:
# Least_Price_bw_2008_2011= 33.73
#            Date  price
# 879  1990-10-26  33.73
# 5495 2008-12-26  33.73

# %% [markdown]
# After reaching peak in Jul-2008, oil prices again when to lowest peak of 33.73 USD/barrel due to U.S. started producing shale gas(Shale gas refers to natural gas that is trapped within shale formations. Shales are fine-grained sedimentary rocks that can be rich resources of petroleum and natural gas). Due to the production America stopped importing petroleum from the OPEC (Organization of the Petroleum Exporting Countries), this increased the supply by approximately 40% and demand being the same the prices started to drop.

# %%
Price_bw_2009_2011=df1['price'][(df1['Date']>'2009-01-15') & (df1['Date']<'2011-02-01')].mean()
print('Mean Price between 2004 & 2008=',round(Price_bw_2009_2011,2))
# Out:
# Mean Price between 2004 & 2008= 72.2

# %% [markdown]
# Post Dec 2008, oil prices continued to increase till 2011 purely due to increase in demand.

# %%
df2=df1.set_index('Date').resample('M').mean()
df2
# Out:
#                 price
# Date
# 1987-05-31  18.580000
# 1987-06-30  18.860476
# 1987-07-31  19.856522
# 1987-08-31  18.979524
# 1987-09-30  18.313182
# ...               ...
# 2022-10-31  93.331905
# 2022-11-30  91.415455
# 2022-12-31  80.924000
# 2023-01-31  82.501429
# 2023-02-28  82.608421
#
# [430 rows x 1 columns]

# %%
fig, ax = plt.subplots(figsize=(30, 10))
sns.lineplot(data=df2,x ="Date",y ="price",color = "red",marker = ".")
# Out:
# <Axes: xlabel='Date', ylabel='price'>

# %%
seasonal_ts_add=smf.tsa.seasonal_decompose(df2["price"],period=10)
seasonal_ts_add.plot()

# %%
#Moving Average
plt.figure(figsize=(14,6))
df2.price.plot(label="org")
for i in range(4,13,4):
    df2["price"].rolling(i).mean().plot(label=str(i))
plt.legend(loc='best')
plt.show()

# %%
#ACF plots and PACF plots
import statsmodels.graphics.tsaplots as tsa_plots
with plt.rc_context():
    plt.rc("figure", figsize=(14,6))
    tsa_plots.plot_acf(df2.price, lags=90)
    plt.show()

# %%
import statsmodels.graphics.tsaplots as tsa_plots
with plt.rc_context():
    plt.rc("figure", figsize=(14,4))
    tsa_plots.plot_pacf(df2.price,lags=45)
    plt.show()

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import calendar
from math import sqrt
from pandas import datetime
import plotly.express as px
from scipy.stats import boxcox
import plotly.graph_objects as go
from pandas.plotting import lag_plot
import statsmodels.formula.api as smf
from plotly.subplots import make_subplots
from statsmodels.tsa.holtwinters import Holt
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.stattools import adfuller
from sklearn.metrics import mean_squared_error
from statsmodels.tools.eval_measures import rmse
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.holtwinters import SimpleExpSmoothing
from statsmodels.tsa.holtwinters import ExponentialSmoothing

import warnings
warnings.filterwarnings('ignore')
# Out:
# C:\Users\marri\AppData\Local\Temp\ipykernel_9924\1798671133.py:7: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   from pandas import datetime

# %%
#Splitting Train and Test Data
#95% data as train & 5% as Test
train_data = df2[:406]
test_data = df2[406:]
train_data.head()
# Out:
#                 price
# Date
# 1987-05-31  18.580000
# 1987-06-30  18.860476
# 1987-07-31  19.856522
# 1987-08-31  18.979524
# 1987-09-30  18.313182

# %%
test_data.head()
# Out:
#                 price
# Date
# 2021-03-31  65.410000
# 2021-04-30  64.806500
# 2021-05-31  68.534211
# 2021-06-30  73.164091
# 2021-07-31  75.165909

# %%
plt.figure(figsize=(12,6))
plt.xlabel('Date')
plt.ylabel('Price')
plt.plot(train_data, 'green', label='Train data')
plt.plot(test_data, 'red', label='Test data')
plt.legend()
plt.show()

# %%
#Evaluation Metric MAPE
def MAPE(pred,org):
    temp = np.abs((pred-org)/org)*100
    return np.mean(temp)

# %%
#Exponential Methods
#Simple Exponential Method
#Using Forecast Attribute
ses_model = SimpleExpSmoothing(train_data['price']).fit(optimized=True)
test_pred_ses = ses_model.forecast(24)
train_pred_ses = ses_model.fittedvalues
test_rmse_ses = sqrt(mean_squared_error(test_pred_ses,test_data.price))
train_rmse_ses = sqrt(mean_squared_error(train_pred_ses,train_data))
mape_ses = MAPE(test_pred_ses,test_data.price)
print('Simple Exponential Method Evaluation',"\n",\
'Mean Absolute Percent Error   = ', mape_ses,"\n",\
'Train Root Mean Squared Error = ',train_rmse_ses,"\n",
'Test Root Mean Squared Error  = ',test_rmse_ses)
# Out:
# Simple Exponential Method Evaluation
#  Mean Absolute Percent Error   =  26.612430554915694
#  Train Root Mean Squared Error =  4.754958582927333
#  Test Root Mean Squared Error  =  30.304161431014755

# %%
#Using Predict Attribute
ses_model = SimpleExpSmoothing(train_data['price']).fit(optimized=True)
test_pred_ses = ses_model.predict(start = test_data.index[0],end = test_data.index[-1])
train_pred_ses = ses_model.fittedvalues
test_rmse_ses = sqrt(mean_squared_error(test_pred_ses,test_data.price))
train_rmse_ses = sqrt(mean_squared_error(train_pred_ses,train_data))
mape_ses = MAPE(test_pred_ses,test_data.price)
print('Simple Exponential Method Evaluation',"\n",\
'Mean Absolute Percent Error   = {}'.format(mape_ses),"\n",\
'Train Root Mean Squared Error = {}'.format(train_rmse_ses),"\n",
'Test Root Mean Squared Error  = {}'.format(test_rmse_ses))
# Out:
# Simple Exponential Method Evaluation
#  Mean Absolute Percent Error   = 26.612430554915694
#  Train Root Mean Squared Error = 4.754958582927333
#  Test Root Mean Squared Error  = 30.304161431014755

# %%
#Difference between Predict and Forecast attribute
plt.figure(figsize=(14,6))
plt.plot(train_data, label='Train')
plt.plot(test_data, label='Test')
plt.plot(test_pred_ses, label='Simple exponential smoothing forcast')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# No seasonality captured. Most recent observation gets higher weightages than the older ones for forecasting.

# %%
#Holt method (Double Exponential)
#Captures both Level and Trend .
dexp_model  = Holt(train_data).fit(optimized=True)
test_pred_dexp = dexp_model.forecast(24)
train_pred_dexp = dexp_model.fittedvalues
test_rmse_dexp = sqrt(mean_squared_error(test_pred_dexp,test_data.price))
train_rmse_dexp = sqrt(mean_squared_error(train_pred_dexp,train_data))
mape_dexp = MAPE(test_pred_dexp,test_data.price)
print('Simple Exponential Method Evaluation',"\n",\
'Mean Absolute Percent Error   = {}'.format(mape_dexp),"\n",\
'Train Root Mean Squared Error = {}'.format(train_rmse_dexp),"\n",
'Test Root Mean Squared Error  = {}'.format(test_rmse_dexp))
# Out:
# Simple Exponential Method Evaluation
#  Mean Absolute Percent Error   = 22.735249166936953
#  Train Root Mean Squared Error = 4.75688180252876
#  Test Root Mean Squared Error  = 26.86314458468191

# %%
plt.figure(figsize=(14,6))
plt.plot(train_data, label='Train')
plt.plot(test_data, label='Test')
plt.plot(test_pred_ses, label='Simple exponential smoothing forcast')
plt.plot(test_pred_dexp, label='Double exponential smoothing forcast')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# Observation We can see that we are able to capture the trend of the data but the level is on another level. We were not able to capture the seasonality.

# %%
#Holts winter exponential smoothing with additive seasonality and trend (Triple Exponential)
texp_add_model  = ExponentialSmoothing(train_data,seasonal="add",trend="add",seasonal_periods=12).fit(optimized=True)
test_pred_ad_texp = texp_add_model.forecast(24)
train_pred_ad_texp = texp_add_model.fittedvalues
test_rmse_ad_texp = sqrt(mean_squared_error(test_pred_ad_texp,test_data.price))
train_rmse_ad_texp = sqrt(mean_squared_error(train_pred_ad_texp,train_data))
mape_ad_texp = MAPE(test_pred_ad_texp,test_data.price)
print('Triple Exponential with Additive Trend and Seosonality Method Evaluation',"\n",\
'Mean Absolute Percent Error   = {}'.format(mape_ad_texp),"\n",\
'Train Root Mean Squared Error = {}'.format(train_rmse_ad_texp),"\n",
'Test Root Mean Squared Error  = {}'.format(test_rmse_ad_texp))
# Out:
# Triple Exponential with Additive Trend and Seosonality Method Evaluation
#  Mean Absolute Percent Error   = 23.756740623206458
#  Train Root Mean Squared Error = 4.697600976046593
#  Test Root Mean Squared Error  = 27.895421403482874

# %%
plt.figure(figsize=(14,6))
plt.plot(train_data, label='Train')
plt.plot(test_data, label='Test')
plt.plot(test_pred_ses, label='Simple exponential smoothing forcast')
plt.plot(test_pred_dexp, label='Double exponential smoothing forcast')
plt.plot(test_pred_ad_texp, label='Triple exponential smoothing forcast with Additive Trend and Sesonal')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# It captures the trend, which we can see that the forecasted values are between simple & double exponential
# It also captures the seasonality. But the errors are higher.

# %%
#Holts winter exponential smoothing with multiplicative seasonality and additive trend (Triple Exponential)
texp_mul_ad_model  = ExponentialSmoothing(train_data,seasonal="mul",trend="add",seasonal_periods=12).fit(optimized=True)
test_pred_mul_ad_texp = texp_mul_ad_model.forecast(24)
train_pred_mul_ad_texp = texp_mul_ad_model.fittedvalues
test_rmse_mul_ad_texp = sqrt(mean_squared_error(test_pred_mul_ad_texp,test_data.price))
train_rmse_mul_ad_texp = sqrt(mean_squared_error(train_pred_mul_ad_texp,train_data))
mape_mul_ad_texp = MAPE(test_pred_mul_ad_texp,test_data.price)
print('Triple Exponential Method with Multiplicative Seasonality and Additive Trend',"\n",\
'Mean Absolute Percent Error   = {}'.format(mape_mul_ad_texp),"\n",\
'Train Root Mean Squared Error = {}'.format(train_rmse_mul_ad_texp),"\n",
'Test Root Mean Squared Error  = {}'.format(test_rmse_mul_ad_texp))
# Out:
# Triple Exponential Method with Multiplicative Seasonality and Additive Trend
#  Mean Absolute Percent Error   = 23.73809343171857
#  Train Root Mean Squared Error = 4.642344220793741
#  Test Root Mean Squared Error  = 27.735156967571474

# %%
plt.figure(figsize=(14,6))
plt.plot(train_data, label='Train')
plt.plot(test_data, label='Test')
plt.plot(test_pred_ses, label='Simple exponential smoothing forcast')
plt.plot(test_pred_dexp, label='Double exponential smoothing forcast')
plt.plot(test_pred_ad_texp, label='Triple exponential smoothing forcast with Additive Trend and Sesonal')
plt.plot(test_pred_mul_ad_texp, label='Triple exponential smoothing forcast with Additive Trend and Multiplicative Sesonal')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# We can see that the trend & error are similar to previous one.

# %%
#Holts winter exponential smoothing with Additive seasonality and multiplicative trend (Triple Exponential)
texp_ad_mul_model  = ExponentialSmoothing(train_data,seasonal="add",trend="mul",seasonal_periods=12).fit(smoothing_level=0.1, smoothing_slope=0.5)
test_pred_ad_mul_texp  = texp_ad_mul_model.forecast(24)
train_pred_ad_mul_texp  = texp_ad_mul_model.fittedvalues
test_rmse_ad_mul_texp  = sqrt(mean_squared_error(test_pred_ad_mul_texp ,test_data.price))
train_rmse_ad_mul_texp  = sqrt(mean_squared_error(train_pred_ad_mul_texp ,train_data))
mape_ad_mul_texp  = MAPE(test_pred_ad_mul_texp,test_data.price)
print('Triple Exponential Method with Additive Seasonality and Multiplicative Trend',"\n",\
'Mean Absolute Percent Error   = {}'.format(mape_ad_mul_texp ),"\n",\
'Train Root Mean Squared Error = {}'.format(train_rmse_ad_mul_texp ),"\n",
'Test Root Mean Squared Error  = {}'.format(test_rmse_ad_mul_texp ))
# Out:
# Triple Exponential Method with Additive Seasonality and Multiplicative Trend
#  Mean Absolute Percent Error   = 25.664398438653013
#  Train Root Mean Squared Error = 13.286500596651736
#  Test Root Mean Squared Error  = 24.42575675504524

# %%
plt.figure(figsize=(14,6))
plt.plot(train_data, label='Train')
plt.plot(test_data, label='Test')
plt.plot(test_pred_ses, label='Simple exponential smoothing forcast')
plt.plot(test_pred_dexp, label='Double exponential smoothing forcast')
plt.plot(test_pred_ad_texp, label='Triple exponential smoothing forcast with Additive Trend and Sesonal')
plt.plot(test_pred_mul_ad_texp, label='Triple exponential smoothing forcast with Additive Trend and Multiplicative Sesonal')
plt.plot(test_pred_ad_mul_texp, label='Triple Exponential Method with Additive Seasonality and Multiplicative Trend')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# With Additive seasonality & multiplicalive trend the error have been increased drastically as it is following most recent trend.

# %%
#Holts winter exponential smoothing with multiplicative seasonality and multiplicative trend (Triple Exponential)
texp_mul_model  = ExponentialSmoothing(train_data,seasonal="mul",trend="mul",seasonal_periods=12).fit(optimized=True)
test_pred_mul_texp  = texp_mul_model.forecast(24)
train_pred_mul_texp  = texp_mul_model.fittedvalues
test_rmse_mul_texp  = sqrt(mean_squared_error(test_pred_mul_texp ,test_data.price))
train_rmse_mul_texp  = sqrt(mean_squared_error(train_pred_mul_texp ,train_data))
mape_mul_texp  = MAPE(test_pred_mul_texp,test_data.price)
print('Triple Exponential Method with multiplicative Trend and Seasonality',"\n",\
'Mean Absolute Percent Error   = {}'.format(mape_mul_texp ),"\n",\
'Train Root Mean Squared Error = {}'.format(train_rmse_mul_texp ),"\n",
'Test Root Mean Squared Error  = {}'.format(test_rmse_mul_texp ))
# Out:
# Triple Exponential Method with multiplicative Trend and Seasonality
#  Mean Absolute Percent Error   = 27.07381190402613
#  Train Root Mean Squared Error = 4.642622854677292
#  Test Root Mean Squared Error  = 30.84972383535443

# %%
plt.figure(figsize=(14,6))
plt.plot(train_data, label='Train')
plt.plot(test_data, label='Test')
plt.plot(test_pred_ses, label='Simple exponential smoothing forcast')
plt.plot(test_pred_dexp, label='Double exponential smoothing forcast')
plt.plot(test_pred_ad_texp, label='Triple exponential smoothing forcast with Additive Trend and Sesonal')
plt.plot(test_pred_mul_ad_texp, label='Triple exponential smoothing forcast with Additive Trend and Multiplicative Sesonal')
plt.plot(test_pred_ad_mul_texp, label='Triple Exponential Method with Additive Seasonality and Multiplicative Trend')
plt.plot(test_pred_mul_texp, label='Triple Exponential Method with multiplicative Trend and Seasonality')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# With Multiplicative seasnoality & trend we are able to capture seasonality but still it has huge error & trend is approximately following simple linear regression.

# %%
#Comparing the results
Evaluation = {"Models":pd.Series(["Simple_Exp","Double_Exp","Triple_Exp_Add","Triple_Exp_Mul_Add","Triple_Exp_Add_Mul","Triple_Exp_Mul"]),
        "Train_RMSE":pd.Series([train_rmse_ses,train_rmse_dexp,train_rmse_ad_texp,train_rmse_mul_ad_texp,train_rmse_ad_mul_texp,train_rmse_mul_texp]),
        "Test_MAPE(%)":pd.Series([mape_ses,mape_dexp,mape_ad_texp,mape_mul_ad_texp,mape_ad_mul_texp,mape_mul_texp]),
        "Test_RMSE_Values":pd.Series([test_rmse_ses,test_rmse_dexp,test_rmse_ad_texp,test_rmse_mul_ad_texp,test_rmse_ad_mul_texp,test_rmse_mul_texp])}
table_evaluation=pd.DataFrame(Evaluation)
table_evaluation.sort_values(['Test_MAPE(%)'], inplace=True, ignore_index=True)
table_evaluation
# Out:
#                Models  Train_RMSE  Test_MAPE(%)  Test_RMSE_Values
# 0          Double_Exp    4.756882     22.735249         26.863145
# 1  Triple_Exp_Mul_Add    4.642344     23.738093         27.735157
# 2      Triple_Exp_Add    4.697601     23.756741         27.895421
# 3  Triple_Exp_Add_Mul   13.286501     25.664398         24.425757
# 4          Simple_Exp    4.754959     26.612431         30.304161
# 5      Triple_Exp_Mul    4.642623     27.073812         30.849724

# %%
#Visualizing Models Performance
f, axe = plt.subplots(1,1, figsize=(14,6))
sns.barplot(x='Test_RMSE_Values', y='Models', data=table_evaluation, ax = axe)
axe.set_xlabel('RMSE', size=16)
axe.set_ylabel('Different_Models', size=16)
plt.yticks(fontsize=14)
plt.xticks(fontsize=14)

for i, v in enumerate(np.round(table_evaluation.Test_RMSE_Values.values,0)):
    axe.text(v + 3, i + .25, str(v), fontsize= 14)
plt.show()

# %%
#Autoregressive Integrated Moving Averages (ARIMA)
#Stationary vs Non-stationary Time Series
#Test of Stationarity
#As we have quarterly data the window size for moving average is equal to 4
def test_stationarity(timeseries):

    # Determine rolling statistics
    movingAverage = timeseries.rolling(window=4).mean()
    movingSTD = timeseries.rolling(window=4).std()

    # Plot rolling statistics
    orig = plt.plot(timeseries, color='blue', label='Original')
    mean = plt.plot(movingAverage, color='red', label='Rolling Mean')
    plt.legend(loc='best')
    plt.title('Rolling Mean')
    plt.show(block=False)

    # Perform Dickey–Fuller test:
    print('Results of Dickey Fuller Test:')
    dftest = adfuller(timeseries['price'], autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print(dfoutput)

# %%
#Augmented Dicky Fuller Test
plt.figure(figsize=(12,4))
price= pd.DataFrame()
price['price'] = df2[['price']]
test_stationarity(price)
# Out:
# Results of Dickey Fuller Test:
# Test Statistic                  -1.650004
# p-value                          0.457038
# #Lags Used                       6.000000
# Number of Observations Used    423.000000
# Critical Value (1%)             -3.445904
# Critical Value (5%)             -2.868397
# Critical Value (10%)            -2.570423
# dtype: float64

# %%
def adf_test(series):
    result = adfuller(series.dropna())
    labels = ['ADF test statistic','p-value','# lags used','# observations']
    out = pd.Series(result[0:4],index=labels)

    if result[1] <= 0.05:
        print("Reject the null hypothesis")
        print("Data is stationary")
    else:
        print("Fail to reject the null hypothesis")
        print("Data is non-stationary")

# %%
adf_test(price.price)
# Out:
# Fail to reject the null hypothesis
# Data is non-stationary

# %%
#Box Cox Transformation
data_boxcox = pd.DataFrame()
data_boxcox['price'] = pd.Series(boxcox(df2['price'], lmbda=0), df2.index)
display(data_boxcox.head())
fig, axis = plt.subplots(2,figsize=(14,6),)
axis[0].plot(data_boxcox)
axis[0].set_title('After Box Cox Transformation')
axis[1].plot(df2, label='original')
axis[1].set_title('Original')
plt.show()
# Out:
#                price
# Date
# 1987-05-31  2.922086
# 1987-06-30  2.937069
# 1987-07-31  2.988533
# 1987-08-31  2.943361
# 1987-09-30  2.907621

# %%
plt.figure(figsize=(12,4))
test_stationarity(data_boxcox)
# Out:
# Results of Dickey Fuller Test:
# Test Statistic                  -1.474833
# p-value                          0.545923
# #Lags Used                       4.000000
# Number of Observations Used    425.000000
# Critical Value (1%)             -3.445831
# Critical Value (5%)             -2.868365
# Critical Value (10%)            -2.570405
# dtype: float64

# %%
adf_test(data_boxcox)
# Out:
# Fail to reject the null hypothesis
# Data is non-stationary

# %%
#Differencing of the Box-Cox Transformation
data_boxcox_diff = data_boxcox - data_boxcox.shift()
data_boxcox_diff.dropna(inplace=True)
plt.figure(figsize=(12,4))
plt.plot(data_boxcox_diff, label='After Box Cox Transformation and Differencing')
plt.legend(loc='best')
plt.show()

# %%
plt.figure(figsize=(12,4))
test_stationarity(data_boxcox_diff)
# Out:
# Results of Dickey Fuller Test:
# Test Statistic                -1.145432e+01
# p-value                        5.755918e-21
# #Lags Used                     3.000000e+00
# Number of Observations Used    4.250000e+02
# Critical Value (1%)           -3.445831e+00
# Critical Value (5%)           -2.868365e+00
# Critical Value (10%)          -2.570405e+00
# dtype: float64

# %%
adf_test(data_boxcox_diff.price)
# Out:
# Reject the null hypothesis
# Data is stationary

# %%
#Building The Time Series Forecasting with Optimal Value using ARIMA
train_data_boxcox = data_boxcox[:406]
test_data_boxcox = data_boxcox[406:]
train_data_boxcox_diff = data_boxcox_diff[:406]
test_data_boxcox_diff = data_boxcox_diff[406:]

# %%
#ARIMA Hyperparameter Tuning
# Grid search ARIMA parameters for a time series
# Evaluate an ARIMA model for a given order (p,d,q) and return RMSE

def evaluate_arima_model(X, arima_order):

# Prepare training dataset
    X = X.astype('float32')
    train_size = int(len(X) * 0.944)
    train, test = X[0:train_size], X[train_size:]
    history = [x for x in train]

# Make predictions
    predictions = list()
    for t in range(len(test)):
        model = ARIMA(history, order=arima_order)
        model_fit = model.fit()
        yhat = model_fit.forecast()[0]
        predictions.append(yhat)
        history.append(test[t])

# Calculate out of sample error
    rmse = sqrt(mean_squared_error(test, predictions))
    return rmse

# Evaluate combinations of p, d and q values for an ARIMA model
def evaluate_models(dataset, p_values, d_values, q_values):
    dataset = dataset.astype('float32')
    best_score, best_cfg = float('inf'), None
    for p in p_values:
        for d in d_values:
            for q in q_values:
                order = (p,d,q)
                try:
                    rmse = evaluate_arima_model(dataset, order)
                    if rmse < best_score:
                        best_score, best_cfg = rmse, order
                except Exception as e:
                    print(e)
                    continue
    print('Best ARIMA%s RMSE=%.3f' % (best_cfg, best_score))

# %%
#Evaluate parameters
#p_values = range(0,5)
#d_values = range(0,5)
#q_values = range(0,5)
#evaluate_models(train_data_boxcox_diff.price, p_values, d_values, q_values)

# %%
#Inverse transformation of the Box-Cox Differencing
model = ARIMA(train_data_boxcox_diff, order=(4, 1, 4))
model_fit1 = model.fit()
y_hat_ar = data_boxcox_diff.copy()
y_hat_ar['arima_forecast'] = model_fit1.predict(data_boxcox_diff.index.min(), data_boxcox_diff.index.max())

# We did differencing. So we need to revert it by adding the consecutive observations.
# For that we are using cumsum() method
y_hat_ar['arima_forecast'] = y_hat_ar['arima_forecast'].cumsum()

# We removed the first observations after differencing as it was null. Hence, adding the first observation back.
y_hat_ar['arima_forecast'] = y_hat_ar['arima_forecast'].add(data_boxcox.price[0])

# Now doing the reverse transformation
# We have done Box Cox Log Log transformation with lambda = 0
# Hence, we have to the exponential as it is the reverse of the log.
y_hat_ar['arima_forecast'] = np.exp(y_hat_ar['arima_forecast'])

# %%
plt.figure(figsize=(12,4))
plt.plot(train_data['price'], label='Train')
plt.plot(test_data, label='Test')
plt.plot(y_hat_ar['arima_forecast'][test_data.index.min():], label='Auto regression forecast (AR)')
plt.legend(loc='best')
plt.show()

# %%
#Model Evaluation
#RMSE (Root Mean Squared Error)
rmse_arima = np.sqrt(mean_squared_error(test_data.price, y_hat_ar['arima_forecast'][test_data.index.min():])).round(2)
rmse_arima
# Out:
# 44.83

# %%
#MAPE (Mean Absolute Percent Error)
mape_arima = round(np.mean(np.abs((test_data.price - y_hat_ar['arima_forecast'][test_data.index.min():])/test_data.price)*100),2)
mape_arima
# Out:
# 45.47

# %%
#Analysing the Residuals
#The mean of the Residual should be zero or close to Zero
model_residual = model_fit1.resid
model_residual.mean()
# Out:
# 0.0006651096552384984

# %%
adf_test(model_residual)
# Out:
# Reject the null hypothesis
# Data is stationary

# %%
#Seasonal Auto Regressive Integrated Moving Average (SARIMA)
#We are only passing the Box Cox because the ARIMAX will perform the differencing internally
#seasonal_order P=2, Q=2, D=2 and m=12 || m=12 . Because the seasonality is monthly.
model = SARIMAX(train_data_boxcox, order=(4,1,4), seasonal_order=(4,1,4,12))
model_fit2= model.fit()
y_hat_sarima = data_boxcox_diff.copy()

# %%
#Inverse Transformation of the Differencing Box-Cox Transformation
y_hat_sarima['sarima_forecast_boxcox'] = model_fit2.predict(data_boxcox_diff.index.min(), data_boxcox_diff.index.max())
y_hat_sarima['sarima_forecast'] = np.exp(y_hat_sarima['sarima_forecast_boxcox'])

# %%
plt.figure(figsize=(14,6))
plt.plot(train_data['price'], label='Train')
plt.plot(test_data, label='Test')
plt.plot(y_hat_sarima['sarima_forecast'][test_data.index.min():], label='SARIMA Forecast')
plt.legend(loc='best')
plt.show()

# %%
rmse_sarima = np.sqrt(mean_squared_error(test_data, y_hat_sarima['sarima_forecast'][test_data.index.min():])).round(2)
rmse_sarima
# Out:
# 30.24

# %%
mape_sarima = round(np.mean(np.abs((test_data.price - y_hat_sarima['sarima_forecast'][test_data.index.min():])/test_data.price)*100),2)
mape_sarima
# Out:
# 27.63

# %%
model_residual = model_fit2.resid
model_residual.mean()
# Out:
# 0.004429262492815684

# %%
adf_test(model_residual)
# Out:
# Reject the null hypothesis
# Data is stationary

# %%
#Comparing the results
Evaluation = {"Models":pd.Series(["Simple_Exponential","Double_Exponential","Triple_Exp_Additive","Triple_Exp_Mul_Add","Triple_Exp_Add_Mul","Triple_Exp_Multiplicative","ARIMA","SARIMA"]),
        "MAPE(%)":pd.Series([mape_ses,mape_dexp,mape_ad_texp,mape_mul_ad_texp,mape_ad_mul_texp,mape_mul_texp,mape_arima,mape_sarima]),\
        "RMSE_Values":pd.Series([test_rmse_ses,test_rmse_dexp,test_rmse_ad_texp,test_rmse_mul_ad_texp,test_rmse_ad_mul_texp,test_rmse_mul_texp,rmse_arima,rmse_sarima])}
table_evaluation=pd.DataFrame(Evaluation)
table_evaluation.sort_values(['RMSE_Values'], inplace=True, ignore_index=True)
table_evaluation
# Out:
#                       Models    MAPE(%)  RMSE_Values
# 0         Triple_Exp_Add_Mul  25.664398    24.425757
# 1         Double_Exponential  22.735249    26.863145
# 2         Triple_Exp_Mul_Add  23.738093    27.735157
# 3        Triple_Exp_Additive  23.756741    27.895421
# 4                     SARIMA  27.630000    30.240000
# 5         Simple_Exponential  26.612431    30.304161
# 6  Triple_Exp_Multiplicative  27.073812    30.849724
# 7                      ARIMA  45.470000    44.830000

# %%
f, axe = plt.subplots(1,1, figsize=(14,6))
sns.barplot(x='RMSE_Values', y='Models', data=table_evaluation, ax = axe)
axe.set_xlabel('RMSE', size=16)
axe.set_ylabel('Different_Models', size=16)
plt.yticks(fontsize=14)
plt.xticks(fontsize=14)

for i, v in enumerate(np.round(table_evaluation.RMSE_Values.values,0)):
    axe.text(v + 3, i + .25, str(v), fontsize= 16)

plt.show()

# %% [markdown]
# Sequence Classification with LSTM Recurrent Neural Networks

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
# Out:
# WARNING:tensorflow:From C:\Users\marri\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
tf.random.set_seed(7)

# %%
# normalize the dataset
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(df2)
#dataset=np.array(df2['price'])
dataset
# Out:
# array([[0.07124613],
#        [0.07352839],
#        [0.08163331],
#        [0.07449709],
#        [0.069075  ],
#        [0.07269231],
#        [0.0647442 ],
#        [0.05882965],
#        [0.05635071],
#        [0.04805152],
#        [0.0399289 ],
#        [0.05509612],
#        [0.0528082 ],
#        [0.04653893],
#        [0.04136359],
#        [0.04125207],
#        [0.02730209],
#        [0.02100534],
#        [0.02604084],
#        [0.04461069],
#        [0.05978832],
#        [0.05748222],
#        [0.07223033],
#        [0.08540061],
#        [0.07167887],
#        [0.06384876],
#        [0.06345776],
#        [0.05651798],
#        [0.06462408],
#        [0.07391288],
#        [0.0724445 ],
#        [0.08149031],
#        [0.09298698],
#        [0.08128324],
#        [0.06967789],
#        [0.05523317],
#        [0.05311889],
#        [0.04296777],
#        [0.05976542],
#        [0.1411226 ],
#        [0.20403547],
#        [0.21317839],
#        [0.18913052],
#        [0.15012311],
#        [0.11182067],
#        [0.0790252 ],
#        [0.07533502],
#        [0.07612839],
#        [0.07618387],
#        [0.06788957],
#        [0.07789379],
#        [0.08095147],
#        [0.08688486],
#        [0.10075196],
#        [0.09182137],
#        [0.06987057],
#        [0.06785814],
#        [0.06696194],
#        [0.06352328],
#        [0.07400499],
#        [0.08189352],
#        [0.09222505],
#        [0.08472541],
#        [0.08066967],
#        [0.08499783],
#        [0.08493125],
#        [0.07640737],
#        [0.06766193],
#        [0.06153043],
#        [0.07032107],
#        [0.072916  ],
#        [0.07201508],
#        [0.0706594 ],
#        [0.06370082],
#        [0.05656236],
#        [0.05591738],
#        [0.05034857],
#        [0.05518892],
#        [0.04371314],
#        [0.03174632],
#        [0.03635017],
#        [0.03236706],
#        [0.03253476],
#        [0.04399969],
#        [0.05178218],
#        [0.0564625 ],
#        [0.06326789],
#        [0.05751662],
#        [0.04939801],
#        [0.05424346],
#        [0.05994665],
#        [0.04969909],
#        [0.05474331],
#        [0.05932121],
#        [0.05844258],
#        [0.07180216],
#        [0.06938199],
#        [0.0609342 ],
#        [0.04906672],
#        [0.05103653],
#        [0.0559445 ],
#        [0.05115489],
#        [0.05725771],
#        [0.06591847],
#        [0.06533194],
#        [0.06651886],
#        [0.08159575],
#        [0.09012827],
#        [0.07592302],
#        [0.0702412 ],
#        [0.07930893],
#        [0.08697011],
#        [0.10420526],
#        [0.11667238],
#        [0.10525533],
#        [0.11358346],
#        [0.11158677],
#        [0.08972163],
#        [0.07574594],
#        [0.062913  ],
#        [0.0748497 ],
#        [0.06310903],
#        [0.07030629],
#        [0.07137225],
#        [0.07027743],
#        [0.08170407],
#        [0.07608128],
#        [0.05986969],
#        [0.04363423],
#        [0.03454374],
#        [0.02668071],
#        [0.03012529],
#        [0.03693326],
#        [0.01938321],
#        [0.01835144],
#        [0.01700422],
#        [0.02863731],
#        [0.02341847],
#        [0.00988464],
#        [0.        ],
#        [0.0104986 ],
#        [0.00363967],
#        [0.02186454],
#        [0.04451168],
#        [0.0439483 ],
#        [0.04913911],
#        [0.07531468],
#        [0.08458322],
#        [0.10349494],
#        [0.09909439],
#        [0.12010202],
#        [0.12733645],
#        [0.12764437],
#        [0.14607258],
#        [0.14371585],
#        [0.10529537],
#        [0.1457626 ],
#        [0.16250741],
#        [0.15345022],
#        [0.1657674 ],
#        [0.18976106],
#        [0.17199083],
#        [0.18493992],
#        [0.1288568 ],
#        [0.1285683 ],
#        [0.14385755],
#        [0.11939557],
#        [0.12883355],
#        [0.15044971],
#        [0.1466693 ],
#        [0.12034243],
#        [0.12901954],
#        [0.12852725],
#        [0.08717716],
#        [0.0730141 ],
#        [0.07226541],
#        [0.0780554 ],
#        [0.08504258],
#        [0.11288096],
#        [0.1294153 ],
#        [0.12629731],
#        [0.11601374],
#        [0.12947593],
#        [0.13692363],
#        [0.15114858],
#        [0.14417932],
#        [0.11807708],
#        [0.15061948],
#        [0.17380319],
#        [0.18671972],
#        [0.16915482],
#        [0.12403742],
#        [0.13046573],
#        [0.14507288],
#        [0.15073499],
#        [0.16326124],
#        [0.14067409],
#        [0.16098066],
#        [0.15402078],
#        [0.16260252],
#        [0.17459506],
#        [0.17115752],
#        [0.19374487],
#        [0.19339141],
#        [0.2257503 ],
#        [0.20635159],
#        [0.23106988],
#        [0.26787177],
#        [0.27155566],
#        [0.32509654],
#        [0.27085291],
#        [0.24230567],
#        [0.28223301],
#        [0.29009345],
#        [0.35217583],
#        [0.34224258],
#        [0.31589176],
#        [0.3623472 ],
#        [0.38810483],
#        [0.4406988 ],
#        [0.431949  ],
#        [0.39639305],
#        [0.36956703],
#        [0.38269947],
#        [0.43257602],
#        [0.40999363],
#        [0.42508618],
#        [0.49177149],
#        [0.48784092],
#        [0.47790513],
#        [0.51955388],
#        [0.51594222],
#        [0.42422193],
#        [0.39044979],
#        [0.39820593],
#        [0.42840061],
#        [0.35686998],
#        [0.38839605],
#        [0.42496959],
#        [0.46919746],
#        [0.46697183],
#        [0.49816493],
#        [0.54604595],
#        [0.49584712],
#        [0.54802455],
#        [0.59006766],
#        [0.67204314],
#        [0.65993966],
#        [0.67012124],
#        [0.69297351],
#        [0.76335129],
#        [0.80758346],
#        [0.91927151],
#        [0.99677933],
#        [1.        ],
#        [0.8415312 ],
#        [0.71126784],
#        [0.50253015],
#        [0.34687114],
#        [0.24511008],
#        [0.27353038],
#        [0.27259654],
#        [0.29876316],
#        [0.32839401],
#        [0.38633501],
#        [0.47834157],
#        [0.44437658],
#        [0.51006834],
#        [0.47050266],
#        [0.51219191],
#        [0.54386521],
#        [0.52591772],
#        [0.53984034],
#        [0.5201871 ],
#        [0.56148521],
#        [0.6102283 ],
#        [0.53803497],
#        [0.52839584],
#        [0.53506086],
#        [0.54693733],
#        [0.55345459],
#        [0.59271029],
#        [0.61394812],
#        [0.66417076],
#        [0.70548023],
#        [0.7640089 ],
#        [0.85292432],
#        [0.92302878],
#        [0.85573625],
#        [0.84633085],
#        [0.87188394],
#        [0.81692633],
#        [0.83819886],
#        [0.81147817],
#        [0.82138994],
#        [0.79781191],
#        [0.82072192],
#        [0.89103461],
#        [0.94082109],
#        [0.89180492],
#        [0.81790261],
#        [0.69435042],
#        [0.75507644],
#        [0.84244869],
#        [0.83844195],
#        [0.82906139],
#        [0.80747937],
#        [0.8110225 ],
#        [0.83922569],
#        [0.86437361],
#        [0.80272265],
#        [0.75206254],
#        [0.75458874],
#        [0.75752513],
#        [0.79832196],
#        [0.82555906],
#        [0.82813075],
#        [0.80762543],
#        [0.79717315],
#        [0.82129694],
#        [0.79982363],
#        [0.80619334],
#        [0.79464212],
#        [0.79687401],
#        [0.8113894 ],
#        [0.8297479 ],
#        [0.78884224],
#        [0.74685409],
#        [0.71010152],
#        [0.63144659],
#        [0.56645294],
#        [0.42728497],
#        [0.30868266],
#        [0.39278773],
#        [0.37480437],
#        [0.4044139 ],
#        [0.44144352],
#        [0.42030925],
#        [0.38030382],
#        [0.29855603],
#        [0.30757342],
#        [0.31413858],
#        [0.28026887],
#        [0.22931301],
#        [0.16986372],
#        [0.1819229 ],
#        [0.23098111],
#        [0.25842657],
#        [0.30040626],
#        [0.31265171],
#        [0.28583697],
#        [0.29308826],
#        [0.29898508],
#        [0.3230274 ],
#        [0.2840646 ],
#        [0.35383543],
#        [0.36415463],
#        [0.36653744],
#        [0.33984474],
#        [0.3456934 ],
#        [0.32957077],
#        [0.29736136],
#        [0.31453381],
#        [0.34078228],
#        [0.37698025],
#        [0.38800496],
#        [0.43036967],
#        [0.44387395],
#        [0.48214752],
#        [0.45155387],
#        [0.45724306],
#        [0.50679258],
#        [0.54641406],
#        [0.52549783],
#        [0.52427181],
#        [0.51022856],
#        [0.5620028 ],
#        [0.57942575],
#        [0.44692127],
#        [0.38682204],
#        [0.40348025],
#        [0.44051182],
#        [0.45823501],
#        [0.4996916 ],
#        [0.50037832],
#        [0.44262747],
#        [0.4401752 ],
#        [0.40048801],
#        [0.43128571],
#        [0.40594984],
#        [0.43442043],
#        [0.46701145],
#        [0.43794827],
#        [0.37294541],
#        [0.18053849],
#        [0.0696065 ],
#        [0.15911825],
#        [0.24771395],
#        [0.27192472],
#        [0.28408013],
#        [0.25294389],
#        [0.24708517],
#        [0.267451  ],
#        [0.32686205],
#        [0.36576035],
#        [0.42680895],
#        [0.45230655],
#        [0.44739581],
#        [0.47772857],
#        [0.51540237],
#        [0.53169137],
#        [0.49573542],
#        [0.52618033],
#        [0.59981669],
#        [0.5795708 ],
#        [0.52359143],
#        [0.62396063],
#        [0.71040725],
#        [0.87409493],
#        [0.77099824],
#        [0.84229841],
#        [0.91857017],
#        [0.8308096 ],
#        [0.73740097],
#        [0.6504837 ],
#        [0.6795099 ],
#        [0.66391555],
#        [0.57854553],
#        [0.59138123],
#        [0.59225183]])

# %%
# split into train and test sets
train_size = int(len(dataset) * 0.944)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]
print(len(train), len(test))
# Out:
# 405 25

# %%
# convert an array of values into a dataset matrix
def create_dataset(dataset, look_back=1):
 dataX, dataY = [], []
 for i in range(len(dataset)-look_back-1):
  a = dataset[i:(i+look_back), 0]
  dataX.append(a)
  dataY.append(dataset[i + look_back, 0])
 return np.array(dataX), np.array(dataY)

# %%
print(create_dataset(dataset))
# Out:
# (array([[0.07124613],
#        [0.07352839],
#        [0.08163331],
#        [0.07449709],
#        [0.069075  ],
#        [0.07269231],
#        [0.0647442 ],
#        [0.05882965],
#        [0.05635071],
#        [0.04805152],
#        [0.0399289 ],
#        [0.05509612],
#        [0.0528082 ],
#        [0.04653893],
#        [0.04136359],
#        [0.04125207],
#        [0.02730209],
#        [0.02100534],
#        [0.02604084],
#        [0.04461069],
#        [0.05978832],
#        [0.05748222],
#        [0.07223033],
#        [0.08540061],
#        [0.07167887],
#        [0.06384876],
#        [0.06345776],
#        [0.05651798],
#        [0.06462408],
#        [0.07391288],
#        [0.0724445 ],
#        [0.08149031],
#        [0.09298698],
#        [0.08128324],
#        [0.06967789],
#        [0.05523317],
#        [0.05311889],
#        [0.04296777],
#        [0.05976542],
#        [0.1411226 ],
#        [0.20403547],
#        [0.21317839],
#        [0.18913052],
#        [0.15012311],
#        [0.11182067],
#        [0.0790252 ],
#        [0.07533502],
#        [0.07612839],
#        [0.07618387],
#        [0.06788957],
#        [0.07789379],
#        [0.08095147],
#        [0.08688486],
#        [0.10075196],
#        [0.09182137],
#        [0.06987057],
#        [0.06785814],
#        [0.06696194],
#        [0.06352328],
#        [0.07400499],
#        [0.08189352],
#        [0.09222505],
#        [0.08472541],
#        [0.08066967],
#        [0.08499783],
#        [0.08493125],
#        [0.07640737],
#        [0.06766193],
#        [0.06153043],
#        [0.07032107],
#        [0.072916  ],
#        [0.07201508],
#        [0.0706594 ],
#        [0.06370082],
#        [0.05656236],
#        [0.05591738],
#        [0.05034857],
#        [0.05518892],
#        [0.04371314],
#        [0.03174632],
#        [0.03635017],
#        [0.03236706],
#        [0.03253476],
#        [0.04399969],
#        [0.05178218],
#        [0.0564625 ],
#        [0.06326789],
#        [0.05751662],
#        [0.04939801],
#        [0.05424346],
#        [0.05994665],
#        [0.04969909],
#        [0.05474331],
#        [0.05932121],
#        [0.05844258],
#        [0.07180216],
#        [0.06938199],
#        [0.0609342 ],
#        [0.04906672],
#        [0.05103653],
#        [0.0559445 ],
#        [0.05115489],
#        [0.05725771],
#        [0.06591847],
#        [0.06533194],
#        [0.06651886],
#        [0.08159575],
#        [0.09012827],
#        [0.07592302],
#        [0.0702412 ],
#        [0.07930893],
#        [0.08697011],
#        [0.10420526],
#        [0.11667238],
#        [0.10525533],
#        [0.11358346],
#        [0.11158677],
#        [0.08972163],
#        [0.07574594],
#        [0.062913  ],
#        [0.0748497 ],
#        [0.06310903],
#        [0.07030629],
#        [0.07137225],
#        [0.07027743],
#        [0.08170407],
#        [0.07608128],
#        [0.05986969],
#        [0.04363423],
#        [0.03454374],
#        [0.02668071],
#        [0.03012529],
#        [0.03693326],
#        [0.01938321],
#        [0.01835144],
#        [0.01700422],
#        [0.02863731],
#        [0.02341847],
#        [0.00988464],
#        [0.        ],
#        [0.0104986 ],
#        [0.00363967],
#        [0.02186454],
#        [0.04451168],
#        [0.0439483 ],
#        [0.04913911],
#        [0.07531468],
#        [0.08458322],
#        [0.10349494],
#        [0.09909439],
#        [0.12010202],
#        [0.12733645],
#        [0.12764437],
#        [0.14607258],
#        [0.14371585],
#        [0.10529537],
#        [0.1457626 ],
#        [0.16250741],
#        [0.15345022],
#        [0.1657674 ],
#        [0.18976106],
#        [0.17199083],
#        [0.18493992],
#        [0.1288568 ],
#        [0.1285683 ],
#        [0.14385755],
#        [0.11939557],
#        [0.12883355],
#        [0.15044971],
#        [0.1466693 ],
#        [0.12034243],
#        [0.12901954],
#        [0.12852725],
#        [0.08717716],
#        [0.0730141 ],
#        [0.07226541],
#        [0.0780554 ],
#        [0.08504258],
#        [0.11288096],
#        [0.1294153 ],
#        [0.12629731],
#        [0.11601374],
#        [0.12947593],
#        [0.13692363],
#        [0.15114858],
#        [0.14417932],
#        [0.11807708],
#        [0.15061948],
#        [0.17380319],
#        [0.18671972],
#        [0.16915482],
#        [0.12403742],
#        [0.13046573],
#        [0.14507288],
#        [0.15073499],
#        [0.16326124],
#        [0.14067409],
#        [0.16098066],
#        [0.15402078],
#        [0.16260252],
#        [0.17459506],
#        [0.17115752],
#        [0.19374487],
#        [0.19339141],
#        [0.2257503 ],
#        [0.20635159],
#        [0.23106988],
#        [0.26787177],
#        [0.27155566],
#        [0.32509654],
#        [0.27085291],
#        [0.24230567],
#        [0.28223301],
#        [0.29009345],
#        [0.35217583],
#        [0.34224258],
#        [0.31589176],
#        [0.3623472 ],
#        [0.38810483],
#        [0.4406988 ],
#        [0.431949  ],
#        [0.39639305],
#        [0.36956703],
#        [0.38269947],
#        [0.43257602],
#        [0.40999363],
#        [0.42508618],
#        [0.49177149],
#        [0.48784092],
#        [0.47790513],
#        [0.51955388],
#        [0.51594222],
#        [0.42422193],
#        [0.39044979],
#        [0.39820593],
#        [0.42840061],
#        [0.35686998],
#        [0.38839605],
#        [0.42496959],
#        [0.46919746],
#        [0.46697183],
#        [0.49816493],
#        [0.54604595],
#        [0.49584712],
#        [0.54802455],
#        [0.59006766],
#        [0.67204314],
#        [0.65993966],
#        [0.67012124],
#        [0.69297351],
#        [0.76335129],
#        [0.80758346],
#        [0.91927151],
#        [0.99677933],
#        [1.        ],
#        [0.8415312 ],
#        [0.71126784],
#        [0.50253015],
#        [0.34687114],
#        [0.24511008],
#        [0.27353038],
#        [0.27259654],
#        [0.29876316],
#        [0.32839401],
#        [0.38633501],
#        [0.47834157],
#        [0.44437658],
#        [0.51006834],
#        [0.47050266],
#        [0.51219191],
#        [0.54386521],
#        [0.52591772],
#        [0.53984034],
#        [0.5201871 ],
#        [0.56148521],
#        [0.6102283 ],
#        [0.53803497],
#        [0.52839584],
#        [0.53506086],
#        [0.54693733],
#        [0.55345459],
#        [0.59271029],
#        [0.61394812],
#        [0.66417076],
#        [0.70548023],
#        [0.7640089 ],
#        [0.85292432],
#        [0.92302878],
#        [0.85573625],
#        [0.84633085],
#        [0.87188394],
#        [0.81692633],
#        [0.83819886],
#        [0.81147817],
#        [0.82138994],
#        [0.79781191],
#        [0.82072192],
#        [0.89103461],
#        [0.94082109],
#        [0.89180492],
#        [0.81790261],
#        [0.69435042],
#        [0.75507644],
#        [0.84244869],
#        [0.83844195],
#        [0.82906139],
#        [0.80747937],
#        [0.8110225 ],
#        [0.83922569],
#        [0.86437361],
#        [0.80272265],
#        [0.75206254],
#        [0.75458874],
#        [0.75752513],
#        [0.79832196],
#        [0.82555906],
#        [0.82813075],
#        [0.80762543],
#        [0.79717315],
#        [0.82129694],
#        [0.79982363],
#        [0.80619334],
#        [0.79464212],
#        [0.79687401],
#        [0.8113894 ],
#        [0.8297479 ],
#        [0.78884224],
#        [0.74685409],
#        [0.71010152],
#        [0.63144659],
#        [0.56645294],
#        [0.42728497],
#        [0.30868266],
#        [0.39278773],
#        [0.37480437],
#        [0.4044139 ],
#        [0.44144352],
#        [0.42030925],
#        [0.38030382],
#        [0.29855603],
#        [0.30757342],
#        [0.31413858],
#        [0.28026887],
#        [0.22931301],
#        [0.16986372],
#        [0.1819229 ],
#        [0.23098111],
#        [0.25842657],
#        [0.30040626],
#        [0.31265171],
#        [0.28583697],
#        [0.29308826],
#        [0.29898508],
#        [0.3230274 ],
#        [0.2840646 ],
#        [0.35383543],
#        [0.36415463],
#        [0.36653744],
#        [0.33984474],
#        [0.3456934 ],
#        [0.32957077],
#        [0.29736136],
#        [0.31453381],
#        [0.34078228],
#        [0.37698025],
#        [0.38800496],
#        [0.43036967],
#        [0.44387395],
#        [0.48214752],
#        [0.45155387],
#        [0.45724306],
#        [0.50679258],
#        [0.54641406],
#        [0.52549783],
#        [0.52427181],
#        [0.51022856],
#        [0.5620028 ],
#        [0.57942575],
#        [0.44692127],
#        [0.38682204],
#        [0.40348025],
#        [0.44051182],
#        [0.45823501],
#        [0.4996916 ],
#        [0.50037832],
#        [0.44262747],
#        [0.4401752 ],
#        [0.40048801],
#        [0.43128571],
#        [0.40594984],
#        [0.43442043],
#        [0.46701145],
#        [0.43794827],
#        [0.37294541],
#        [0.18053849],
#        [0.0696065 ],
#        [0.15911825],
#        [0.24771395],
#        [0.27192472],
#        [0.28408013],
#        [0.25294389],
#        [0.24708517],
#        [0.267451  ],
#        [0.32686205],
#        [0.36576035],
#        [0.42680895],
#        [0.45230655],
#        [0.44739581],
#        [0.47772857],
#        [0.51540237],
#        [0.53169137],
#        [0.49573542],
#        [0.52618033],
#        [0.59981669],
#        [0.5795708 ],
#        [0.52359143],
#        [0.62396063],
#        [0.71040725],
#        [0.87409493],
#        [0.77099824],
#        [0.84229841],
#        [0.91857017],
#        [0.8308096 ],
#        [0.73740097],
#        [0.6504837 ],
#        [0.6795099 ],
#        [0.66391555],
#        [0.57854553]]), array([0.07352839, 0.08163331, 0.07449709, 0.069075  , 0.07269231,
#        0.0647442 , 0.05882965, 0.05635071, 0.04805152, 0.0399289 ,
#        0.05509612, 0.0528082 , 0.04653893, 0.04136359, 0.04125207,
#        0.02730209, 0.02100534, 0.02604084, 0.04461069, 0.05978832,
#        0.05748222, 0.07223033, 0.08540061, 0.07167887, 0.06384876,
#        0.06345776, 0.05651798, 0.06462408, 0.07391288, 0.0724445 ,
#        0.08149031, 0.09298698, 0.08128324, 0.06967789, 0.05523317,
#        0.05311889, 0.04296777, 0.05976542, 0.1411226 , 0.20403547,
#        0.21317839, 0.18913052, 0.15012311, 0.11182067, 0.0790252 ,
#        0.07533502, 0.07612839, 0.07618387, 0.06788957, 0.07789379,
#        0.08095147, 0.08688486, 0.10075196, 0.09182137, 0.06987057,
#        0.06785814, 0.06696194, 0.06352328, 0.07400499, 0.08189352,
#        0.09222505, 0.08472541, 0.08066967, 0.08499783, 0.08493125,
#        0.07640737, 0.06766193, 0.06153043, 0.07032107, 0.072916  ,
#        0.07201508, 0.0706594 , 0.06370082, 0.05656236, 0.05591738,
#        0.05034857, 0.05518892, 0.04371314, 0.03174632, 0.03635017,
#        0.03236706, 0.03253476, 0.04399969, 0.05178218, 0.0564625 ,
#        0.06326789, 0.05751662, 0.04939801, 0.05424346, 0.05994665,
#        0.04969909, 0.05474331, 0.05932121, 0.05844258, 0.07180216,
#        0.06938199, 0.0609342 , 0.04906672, 0.05103653, 0.0559445 ,
#        0.05115489, 0.05725771, 0.06591847, 0.06533194, 0.06651886,
#        0.08159575, 0.09012827, 0.07592302, 0.0702412 , 0.07930893,
#        0.08697011, 0.10420526, 0.11667238, 0.10525533, 0.11358346,
#        0.11158677, 0.08972163, 0.07574594, 0.062913  , 0.0748497 ,
#        0.06310903, 0.07030629, 0.07137225, 0.07027743, 0.08170407,
#        0.07608128, 0.05986969, 0.04363423, 0.03454374, 0.02668071,
#        0.03012529, 0.03693326, 0.01938321, 0.01835144, 0.01700422,
#        0.02863731, 0.02341847, 0.00988464, 0.        , 0.0104986 ,
#        0.00363967, 0.02186454, 0.04451168, 0.0439483 , 0.04913911,
#        0.07531468, 0.08458322, 0.10349494, 0.09909439, 0.12010202,
#        0.12733645, 0.12764437, 0.14607258, 0.14371585, 0.10529537,
#        0.1457626 , 0.16250741, 0.15345022, 0.1657674 , 0.18976106,
#        0.17199083, 0.18493992, 0.1288568 , 0.1285683 , 0.14385755,
#        0.11939557, 0.12883355, 0.15044971, 0.1466693 , 0.12034243,
#        0.12901954, 0.12852725, 0.08717716, 0.0730141 , 0.07226541,
#        0.0780554 , 0.08504258, 0.11288096, 0.1294153 , 0.12629731,
#        0.11601374, 0.12947593, 0.13692363, 0.15114858, 0.14417932,
#        0.11807708, 0.15061948, 0.17380319, 0.18671972, 0.16915482,
#        0.12403742, 0.13046573, 0.14507288, 0.15073499, 0.16326124,
#        0.14067409, 0.16098066, 0.15402078, 0.16260252, 0.17459506,
#        0.17115752, 0.19374487, 0.19339141, 0.2257503 , 0.20635159,
#        0.23106988, 0.26787177, 0.27155566, 0.32509654, 0.27085291,
#        0.24230567, 0.28223301, 0.29009345, 0.35217583, 0.34224258,
#        0.31589176, 0.3623472 , 0.38810483, 0.4406988 , 0.431949  ,
#        0.39639305, 0.36956703, 0.38269947, 0.43257602, 0.40999363,
#        0.42508618, 0.49177149, 0.48784092, 0.47790513, 0.51955388,
#        0.51594222, 0.42422193, 0.39044979, 0.39820593, 0.42840061,
#        0.35686998, 0.38839605, 0.42496959, 0.46919746, 0.46697183,
#        0.49816493, 0.54604595, 0.49584712, 0.54802455, 0.59006766,
#        0.67204314, 0.65993966, 0.67012124, 0.69297351, 0.76335129,
#        0.80758346, 0.91927151, 0.99677933, 1.        , 0.8415312 ,
#        0.71126784, 0.50253015, 0.34687114, 0.24511008, 0.27353038,
#        0.27259654, 0.29876316, 0.32839401, 0.38633501, 0.47834157,
#        0.44437658, 0.51006834, 0.47050266, 0.51219191, 0.54386521,
#        0.52591772, 0.53984034, 0.5201871 , 0.56148521, 0.6102283 ,
#        0.53803497, 0.52839584, 0.53506086, 0.54693733, 0.55345459,
#        0.59271029, 0.61394812, 0.66417076, 0.70548023, 0.7640089 ,
#        0.85292432, 0.92302878, 0.85573625, 0.84633085, 0.87188394,
#        0.81692633, 0.83819886, 0.81147817, 0.82138994, 0.79781191,
#        0.82072192, 0.89103461, 0.94082109, 0.89180492, 0.81790261,
#        0.69435042, 0.75507644, 0.84244869, 0.83844195, 0.82906139,
#        0.80747937, 0.8110225 , 0.83922569, 0.86437361, 0.80272265,
#        0.75206254, 0.75458874, 0.75752513, 0.79832196, 0.82555906,
#        0.82813075, 0.80762543, 0.79717315, 0.82129694, 0.79982363,
#        0.80619334, 0.79464212, 0.79687401, 0.8113894 , 0.8297479 ,
#        0.78884224, 0.74685409, 0.71010152, 0.63144659, 0.56645294,
#        0.42728497, 0.30868266, 0.39278773, 0.37480437, 0.4044139 ,
#        0.44144352, 0.42030925, 0.38030382, 0.29855603, 0.30757342,
#        0.31413858, 0.28026887, 0.22931301, 0.16986372, 0.1819229 ,
#        0.23098111, 0.25842657, 0.30040626, 0.31265171, 0.28583697,
#        0.29308826, 0.29898508, 0.3230274 , 0.2840646 , 0.35383543,
#        0.36415463, 0.36653744, 0.33984474, 0.3456934 , 0.32957077,
#        0.29736136, 0.31453381, 0.34078228, 0.37698025, 0.38800496,
#        0.43036967, 0.44387395, 0.48214752, 0.45155387, 0.45724306,
#        0.50679258, 0.54641406, 0.52549783, 0.52427181, 0.51022856,
#        0.5620028 , 0.57942575, 0.44692127, 0.38682204, 0.40348025,
#        0.44051182, 0.45823501, 0.4996916 , 0.50037832, 0.44262747,
#        0.4401752 , 0.40048801, 0.43128571, 0.40594984, 0.43442043,
#        0.46701145, 0.43794827, 0.37294541, 0.18053849, 0.0696065 ,
#        0.15911825, 0.24771395, 0.27192472, 0.28408013, 0.25294389,
#        0.24708517, 0.267451  , 0.32686205, 0.36576035, 0.42680895,
#        0.45230655, 0.44739581, 0.47772857, 0.51540237, 0.53169137,
#        0.49573542, 0.52618033, 0.59981669, 0.5795708 , 0.52359143,
#        0.62396063, 0.71040725, 0.87409493, 0.77099824, 0.84229841,
#        0.91857017, 0.8308096 , 0.73740097, 0.6504837 , 0.6795099 ,
#        0.66391555, 0.57854553, 0.59138123]))

# %%
# reshape into X=t and Y=t+1
look_back = 1
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)

# %%
# reshape input to be [samples, time steps, features]
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# %%
# create and fit the LSTM network
model = Sequential()
model.add(LSTM(4, input_shape=(1, look_back)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(trainX, trainY, epochs=100, batch_size=1, verbose=2)
# Out:
# WARNING:tensorflow:From C:\Users\marri\anaconda3\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\marri\anaconda3\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/100
# WARNING:tensorflow:From C:\Users\marri\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 403/403 - 4s - loss: 0.0462 - 4s/epoch - 11ms/step
# Epoch 2/100
# 403/403 - 1s - loss: 0.0156 - 1s/epoch - 3ms/step
# Epoch 3/100
# 403/403 - 1s - loss: 0.0052 - 1s/epoch - 3ms/step
# Epoch 4/100
# 403/403 - 1s - loss: 0.0020 - 1s/epoch - 3ms/step
# Epoch 5/100
# 403/403 - 1s - loss: 0.0018 - 1s/epoch - 3ms/step
# Epoch 6/100
# 403/403 - 1s - loss: 0.0018 - 1s/epoch - 3ms/step
# Epoch 7/100
# 403/403 - 1s - loss: 0.0017 - 1s/epoch - 3ms/step
# Epoch 8/100
# 403/403 - 1s - loss: 0.0017 - 1s/epoch - 3ms/step
# Epoch 9/100
# 403/403 - 1s - loss: 0.0017 - 1s/epoch - 3ms/step
# Epoch 10/100
# 403/403 - 1s - loss: 0.0017 - 1s/epoch - 3ms/step
# Epoch 11/100
# 403/403 - 1s - loss: 0.0017 - 907ms/epoch - 2ms/step
# Epoch 12/100
# 403/403 - 1s - loss: 0.0017 - 916ms/epoch - 2ms/step
# Epoch 13/100
# 403/403 - 1s - loss: 0.0017 - 868ms/epoch - 2ms/step
# Epoch 14/100
# 403/403 - 1s - loss: 0.0016 - 888ms/epoch - 2ms/step
# Epoch 15/100
# 403/403 - 1s - loss: 0.0016 - 1s/epoch - 3ms/step
# Epoch 16/100
# 403/403 - 1s - loss: 0.0016 - 1s/epoch - 3ms/step
# Epoch 17/100
# 403/403 - 1s - loss: 0.0016 - 1s/epoch - 3ms/step
# Epoch 18/100
# 403/403 - 1s - loss: 0.0016 - 1s/epoch - 3ms/step
# Epoch 19/100
# 403/403 - 1s - loss: 0.0016 - 1s/epoch - 3ms/step
# Epoch 20/100
# 403/403 - 1s - loss: 0.0016 - 1s/epoch - 3ms/step
# Epoch 21/100
# 403/403 - 1s - loss: 0.0016 - 1s/epoch - 3ms/step
# Epoch 22/100
# 403/403 - 1s - loss: 0.0016 - 1s/epoch - 3ms/step
# Epoch 23/100
# 403/403 - 1s - loss: 0.0016 - 1s/epoch - 3ms/step
# Epoch 24/100
# 403/403 - 1s - loss: 0.0016 - 1s/epoch - 3ms/step
# Epoch 25/100
# 403/403 - 1s - loss: 0.0016 - 1s/epoch - 3ms/step
# Epoch 26/100
# 403/403 - 1s - loss: 0.0015 - 1s/epoch - 3ms/step
# Epoch 27/100
# 403/403 - 1s - loss: 0.0016 - 1s/epoch - 2ms/step
# Epoch 28/100
# 403/403 - 1s - loss: 0.0016 - 938ms/epoch - 2ms/step
# Epoch 29/100
# 403/403 - 1s - loss: 0.0016 - 881ms/epoch - 2ms/step
# Epoch 30/100
# 403/403 - 1s - loss: 0.0016 - 872ms/epoch - 2ms/step
# Epoch 31/100
# 403/403 - 1s - loss: 0.0016 - 992ms/epoch - 2ms/step
# Epoch 32/100
# 403/403 - 1s - loss: 0.0016 - 1s/epoch - 3ms/step
# Epoch 33/100
# 403/403 - 1s - loss: 0.0016 - 1s/epoch - 3ms/step
# Epoch 34/100
# 403/403 - 1s - loss: 0.0015 - 1s/epoch - 3ms/step
# Epoch 35/100
# 403/403 - 1s - loss: 0.0016 - 1s/epoch - 3ms/step
# Epoch 36/100
# 403/403 - 1s - loss: 0.0016 - 1s/epoch - 3ms/step
# Epoch 37/100
# 403/403 - 1s - loss: 0.0016 - 1s/epoch - 3ms/step
# Epoch 38/100
# 403/403 - 1s - loss: 0.0016 - 1s/epoch - 3ms/step
# Epoch 39/100
# 403/403 - 1s - loss: 0.0015 - 1s/epoch - 3ms/step
# Epoch 40/100
# 403/403 - 1s - loss: 0.0016 - 1s/epoch - 3ms/step
# Epoch 41/100
# 403/403 - 1s - loss: 0.0016 - 1s/epoch - 3ms/step
# Epoch 42/100
# 403/403 - 1s - loss: 0.0016 - 942ms/epoch - 2ms/step
# Epoch 43/100
# 403/403 - 1s - loss: 0.0016 - 901ms/epoch - 2ms/step
# Epoch 44/100
# 403/403 - 1s - loss: 0.0016 - 959ms/epoch - 2ms/step
# Epoch 45/100
# 403/403 - 1s - loss: 0.0015 - 920ms/epoch - 2ms/step
# Epoch 46/100
# 403/403 - 1s - loss: 0.0016 - 909ms/epoch - 2ms/step
# Epoch 47/100
# 403/403 - 1s - loss: 0.0015 - 1s/epoch - 3ms/step
# Epoch 48/100
# 403/403 - 1s - loss: 0.0016 - 1s/epoch - 3ms/step
# Epoch 49/100
# 403/403 - 1s - loss: 0.0015 - 1s/epoch - 3ms/step
# Epoch 50/100
# 403/403 - 1s - loss: 0.0015 - 1s/epoch - 3ms/step
# Epoch 51/100
# 403/403 - 1s - loss: 0.0015 - 1s/epoch - 3ms/step
# Epoch 52/100
# 403/403 - 1s - loss: 0.0016 - 1s/epoch - 3ms/step
# Epoch 53/100
# 403/403 - 1s - loss: 0.0016 - 1s/epoch - 3ms/step
# Epoch 54/100
# 403/403 - 1s - loss: 0.0015 - 1s/epoch - 3ms/step
# Epoch 55/100
# 403/403 - 1s - loss: 0.0016 - 1s/epoch - 3ms/step
# Epoch 56/100
# 403/403 - 1s - loss: 0.0016 - 1s/epoch - 3ms/step
# Epoch 57/100
# 403/403 - 1s - loss: 0.0016 - 958ms/epoch - 2ms/step
# Epoch 58/100
# 403/403 - 1s - loss: 0.0016 - 894ms/epoch - 2ms/step
# Epoch 59/100
# 403/403 - 1s - loss: 0.0016 - 881ms/epoch - 2ms/step
# Epoch 60/100
# 403/403 - 1s - loss: 0.0016 - 1s/epoch - 3ms/step
# Epoch 61/100
# 403/403 - 1s - loss: 0.0015 - 1s/epoch - 3ms/step
# Epoch 62/100
# 403/403 - 1s - loss: 0.0016 - 1s/epoch - 3ms/step
# Epoch 63/100
# 403/403 - 1s - loss: 0.0016 - 1s/epoch - 3ms/step
# Epoch 64/100
# 403/403 - 1s - loss: 0.0016 - 1s/epoch - 3ms/step
# Epoch 65/100
# 403/403 - 1s - loss: 0.0016 - 1s/epoch - 3ms/step
# Epoch 66/100
# 403/403 - 1s - loss: 0.0016 - 1s/epoch - 3ms/step
# Epoch 67/100
# 403/403 - 1s - loss: 0.0016 - 1s/epoch - 3ms/step
# Epoch 68/100
# 403/403 - 1s - loss: 0.0016 - 1s/epoch - 3ms/step
# Epoch 69/100
# 403/403 - 1s - loss: 0.0016 - 1s/epoch - 3ms/step
# Epoch 70/100
# 403/403 - 1s - loss: 0.0015 - 1s/epoch - 3ms/step
# Epoch 71/100
# 403/403 - 1s - loss: 0.0016 - 1s/epoch - 3ms/step
# Epoch 72/100
# 403/403 - 1s - loss: 0.0016 - 936ms/epoch - 2ms/step
# Epoch 73/100
# 403/403 - 1s - loss: 0.0015 - 877ms/epoch - 2ms/step
# Epoch 74/100
# 403/403 - 1s - loss: 0.0016 - 896ms/epoch - 2ms/step
# Epoch 75/100
# 403/403 - 1s - loss: 0.0016 - 1s/epoch - 3ms/step
# Epoch 76/100
# 403/403 - 1s - loss: 0.0016 - 1s/epoch - 3ms/step
# Epoch 77/100
# 403/403 - 1s - loss: 0.0016 - 1s/epoch - 3ms/step
# Epoch 78/100
# 403/403 - 1s - loss: 0.0016 - 1s/epoch - 3ms/step
# Epoch 79/100
# 403/403 - 1s - loss: 0.0015 - 1s/epoch - 3ms/step
# Epoch 80/100
# 403/403 - 1s - loss: 0.0016 - 1s/epoch - 3ms/step
# Epoch 81/100
# 403/403 - 1s - loss: 0.0016 - 1s/epoch - 3ms/step
# Epoch 82/100
# 403/403 - 1s - loss: 0.0016 - 1s/epoch - 3ms/step
# Epoch 83/100
# 403/403 - 1s - loss: 0.0016 - 1s/epoch - 3ms/step
# Epoch 84/100
# 403/403 - 1s - loss: 0.0016 - 1s/epoch - 3ms/step
# Epoch 85/100
# 403/403 - 1s - loss: 0.0016 - 968ms/epoch - 2ms/step
# Epoch 86/100
# 403/403 - 1s - loss: 0.0016 - 971ms/epoch - 2ms/step
# Epoch 87/100
# 403/403 - 1s - loss: 0.0016 - 945ms/epoch - 2ms/step
# Epoch 88/100
# 403/403 - 1s - loss: 0.0015 - 919ms/epoch - 2ms/step
# Epoch 89/100
# 403/403 - 1s - loss: 0.0016 - 876ms/epoch - 2ms/step
# Epoch 90/100
# 403/403 - 1s - loss: 0.0015 - 997ms/epoch - 2ms/step
# Epoch 91/100
# 403/403 - 1s - loss: 0.0015 - 1s/epoch - 3ms/step
# Epoch 92/100
# 403/403 - 1s - loss: 0.0016 - 1s/epoch - 3ms/step
# Epoch 93/100
# 403/403 - 1s - loss: 0.0016 - 1s/epoch - 3ms/step
# Epoch 94/100
# 403/403 - 1s - loss: 0.0016 - 1s/epoch - 3ms/step
# Epoch 95/100
# 403/403 - 1s - loss: 0.0016 - 1s/epoch - 3ms/step
# Epoch 96/100
# 403/403 - 1s - loss: 0.0016 - 1s/epoch - 3ms/step
# Epoch 97/100
# 403/403 - 1s - loss: 0.0015 - 1s/epoch - 3ms/step
# Epoch 98/100
# 403/403 - 1s - loss: 0.0015 - 1s/epoch - 3ms/step
# Epoch 99/100
# 403/403 - 1s - loss: 0.0016 - 1s/epoch - 3ms/step
# Epoch 100/100
# 403/403 - 1s - loss: 0.0016 - 1s/epoch - 3ms/step

# %%
# make predictions
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)
# invert predictions
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])
# calculate root mean squared error
trainScore = np.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = np.sqrt(mean_squared_error(testY[0], testPredict[:,0]))
print('Test Score: %.2f RMSE' % (testScore))
# Out:
# 13/13 [==============================] - 1s 4ms/step
# 1/1 [==============================] - 0s 22ms/step
# Train Score: 4.83 RMSE
# Test Score: 8.27 RMSE

# %%
trainPredict
# Out:
# array([[ 19.80546 ],
#        [ 20.070852],
#        [ 21.01615 ],
#        [ 20.183605],
#        [ 19.553322],
#        [ 19.973587],
#        [ 19.051338],
#        [ 18.367893],
#        [ 18.082176],
#        [ 17.128841],
#        [ 16.200663],
#        [ 17.937744],
#        [ 17.67464 ],
#        [ 16.955627],
#        [ 16.364248],
#        [ 16.351528],
#        [ 14.767626],
#        [ 14.057587],
#        [ 14.625155],
#        [ 16.73506 ],
#        [ 18.478502],
#        [ 18.21254 ],
#        [ 19.919863],
#        [ 21.457016],
#        [ 19.855755],
#        [ 18.947714],
#        [ 18.902477],
#        [ 18.10144 ],
#        [ 19.037436],
#        [ 20.115597],
#        [ 19.944769],
#        [ 20.999434],
#        [ 22.34759 ],
#        [ 20.97523 ],
#        [ 19.623304],
#        [ 17.953516],
#        [ 17.710342],
#        [ 16.547346],
#        [ 18.475863],
#        [ 28.078775],
#        [ 35.74671 ],
#        [ 36.87465 ],
#        [ 33.91463 ],
#        [ 29.164557],
#        [ 24.57399 ],
#        [ 20.711481],
#        [ 20.281183],
#        [ 20.37362 ],
#        [ 20.380085],
#        [ 19.41579 ],
#        [ 20.579456],
#        [ 20.936457],
#        [ 21.630964],
#        [ 23.26289 ],
#        [ 22.210514],
#        [ 19.645676],
#        [ 19.412144],
#        [ 19.308235],
#        [ 18.910057],
#        [ 20.126318],
#        [ 21.04657 ],
#        [ 22.25798 ],
#        [ 21.377932],
#        [ 20.90353 ],
#        [ 21.409838],
#        [ 21.402037],
#        [ 20.406132],
#        [ 19.389389],
#        [ 18.679672],
#        [ 19.69799 ],
#        [ 19.999607],
#        [ 19.894836],
#        [ 19.73729 ],
#        [ 18.930597],
#        [ 18.106554],
#        [ 18.032278],
#        [ 17.392206],
#        [ 17.948421],
#        [ 16.632483],
#        [ 15.27062 ],
#        [ 15.793278],
#        [ 15.340996],
#        [ 15.360014],
#        [ 16.665226],
#        [ 17.55677 ],
#        [ 18.095053],
#        [ 18.880518],
#        [ 18.2165  ],
#        [ 17.283176],
#        [ 17.839647],
#        [ 18.496778],
#        [ 17.317701],
#        [ 17.897146],
#        [ 18.424599],
#        [ 18.32325 ],
#        [ 19.870085],
#        [ 19.588951],
#        [ 18.610802],
#        [ 17.24519 ],
#        [ 17.471159],
#        [ 18.0354  ],
#        [ 17.484745],
#        [ 18.186665],
#        [ 19.187319],
#        [ 19.119389],
#        [ 19.256882],
#        [ 21.011759],
#        [ 22.011568],
#        [ 20.349686],
#        [ 19.688715],
#        [ 20.744604],
#        [ 21.640957],
#        [ 23.671146],
#        [ 25.150969],
#        [ 23.79543 ],
#        [ 24.783466],
#        [ 24.54621 ],
#        [ 21.963812],
#        [ 20.329054],
#        [ 18.839478],
#        [ 20.224659],
#        [ 18.862143],
#        [ 19.696276],
#        [ 19.820118],
#        [ 19.692923],
#        [ 21.024422],
#        [ 20.368128],
#        [ 18.487896],
#        [ 16.623468],
#        [ 15.588008],
#        [ 14.697418],
#        [ 15.086977],
#        [ 15.859586],
#        [ 13.875174],
#        [ 13.759256],
#        [ 13.608028],
#        [ 14.918586],
#        [ 14.329331],
#        [ 12.811245],
#        [ 11.711838],
#        [ 12.879796],
#        [ 12.115722],
#        [ 14.154289],
#        [ 16.723742],
#        [ 16.659353],
#        [ 17.253489],
#        [ 20.278814],
#        [ 21.361282],
#        [ 23.587109],
#        [ 23.067188],
#        [ 25.559654],
#        [ 26.423904],
#        [ 26.460756],
#        [ 28.675407],
#        [ 28.39119 ],
#        [ 23.800167],
#        [ 28.638006],
#        [ 30.665094],
#        [ 29.56695 ],
#        [ 31.061306],
#        [ 33.991962],
#        [ 31.819035],
#        [ 33.40112 ],
#        [ 26.605904],
#        [ 26.571358],
#        [ 28.408266],
#        [ 25.475416],
#        [ 26.60312 ],
#        [ 29.204031],
#        [ 28.747416],
#        [ 25.588327],
#        [ 26.625395],
#        [ 26.566442],
#        [ 21.665237],
#        [ 20.011017],
#        [ 19.923943],
#        [ 20.59831 ],
#        [ 21.41508 ],
#        [ 24.699965],
#        [ 26.672792],
#        [ 26.299587],
#        [ 25.072561],
#        [ 26.680052],
#        [ 27.573664],
#        [ 29.288517],
#        [ 28.44706 ],
#        [ 25.318272],
#        [ 29.22455 ],
#        [ 32.040024],
#        [ 33.61913 ],
#        [ 31.473522],
#        [ 26.029425],
#        [ 26.798641],
#        [ 28.55481 ],
#        [ 29.238514],
#        [ 30.756668],
#        [ 28.02478 ],
#        [ 30.479706],
#        [ 29.63601 ],
#        [ 30.676643],
#        [ 32.13663 ],
#        [ 31.717476],
#        [ 34.480885],
#        [ 34.437485],
#        [ 38.43032 ],
#        [ 36.032158],
#        [ 39.09012 ],
#        [ 43.676388],
#        [ 44.137295],
#        [ 50.86217 ],
#        [ 44.04935 ],
#        [ 40.486492],
#        [ 45.474743],
#        [ 46.460705],
#        [ 54.275055],
#        [ 53.02267 ],
#        [ 49.70329 ],
#        [ 55.55773 ],
#        [ 58.80568 ],
#        [ 65.42398 ],
#        [ 64.32507 ],
#        [ 59.85028 ],
#        [ 56.46825 ],
#        [ 58.12423 ],
#        [ 64.40386 ],
#        [ 61.563408],
#        [ 63.462433],
#        [ 71.81124 ],
#        [ 71.32162 ],
#        [ 70.08235 ],
#        [ 75.260796],
#        [ 74.81352 ],
#        [ 63.353752],
#        [ 59.101265],
#        [ 60.078712],
#        [ 63.879128],
#        [ 54.86699 ],
#        [ 58.842392],
#        [ 63.44777 ],
#        [ 68.99449 ],
#        [ 68.71619 ],
#        [ 72.60685 ],
#        [ 78.52961 ],
#        [ 72.31853 ],
#        [ 78.77284 ],
#        [ 83.90953 ],
#        [ 93.721176],
#        [ 92.29129 ],
#        [ 93.49459 ],
#        [ 96.177315],
#        [104.272675],
#        [109.223526],
#        [121.219635],
#        [129.10182 ],
#        [129.42136 ],
#        [112.94769 ],
#        [ 98.30637 ],
#        [ 73.14947 ],
#        [ 53.606197],
#        [ 40.835583],
#        [ 44.384483],
#        [ 44.26757 ],
#        [ 47.549362],
#        [ 51.277508],
#        [ 58.582577],
#        [ 70.13683 ],
#        [ 65.88554 ],
#        [ 74.08534 ],
#        [ 69.15765 ],
#        [ 74.34871 ],
#        [ 78.26135 ],
#        [ 76.04795 ],
#        [ 77.765854],
#        [ 75.33916 ],
#        [ 80.42426 ],
#        [ 86.349106],
#        [ 77.543434],
#        [ 76.35415 ],
#        [ 77.17679 ],
#        [ 78.639206],
#        [ 79.439766],
#        [ 84.23022 ],
#        [ 86.79743 ],
#        [ 92.79194 ],
#        [ 97.63465 ],
#        [104.34708 ],
#        [114.1825  ],
#        [121.61019 ],
#        [114.48608 ],
#        [113.46883 ],
#        [116.22036 ],
#        [110.25512 ],
#        [112.58508 ],
#        [109.654175],
#        [110.74619 ],
#        [108.13929 ],
#        [110.672775],
#        [118.25699 ],
#        [123.44805 ],
#        [118.33844 ],
#        [110.362625],
#        [ 96.33814 ],
#        [103.33446 ],
#        [113.04743 ],
#        [112.61155 ],
#        [111.58747 ],
#        [109.212006],
#        [109.603836],
#        [112.69691 ],
#        [115.415665],
#        [108.68487 ],
#        [102.9918  ],
#        [103.27903 ],
#        [103.61249 ],
#        [108.196   ],
#        [111.20382 ],
#        [111.485596],
#        [109.22817 ],
#        [108.06821 ],
#        [110.73598 ],
#        [108.36293 ],
#        [109.06962 ],
#        [107.78639 ],
#        [108.03493 ],
#        [109.644356],
#        [111.66261 ],
#        [107.13924 ],
#        [102.398506],
#        [ 98.171135],
#        [ 88.89862 ],
#        [ 81.03213 ],
#        [ 63.73888 ],
#        [ 48.79629 ],
#        [ 59.395935],
#        [ 57.12871 ],
#        [ 60.86077 ],
#        [ 65.51746 ],
#        [ 62.86164 ],
#        [ 57.822174],
#        [ 47.52334 ],
#        [ 48.656788],
#        [ 49.48266 ],
#        [ 45.22855 ],
#        [ 38.87211 ],
#        [ 31.55985 ],
#        [ 33.031864],
#        [ 39.079098],
#        [ 42.496044],
#        [ 47.75581 ],
#        [ 49.295586],
#        [ 45.926666],
#        [ 46.83663 ],
#        [ 47.57724 ],
#        [ 50.601593],
#        [ 45.704384],
#        [ 54.48432 ],
#        [ 55.78567 ],
#        [ 56.08618 ],
#        [ 52.720413],
#        [ 53.457706],
#        [ 51.425747],
#        [ 47.373257],
#        [ 49.532394],
#        [ 52.838596],
#        [ 57.403095],
#        [ 58.79309 ],
#        [ 64.12662 ],
#        [ 65.82248 ],
#        [ 70.61177 ],
#        [ 66.78566 ],
#        [ 67.49853 ],
#        [ 73.67884 ],
#        [ 78.574875],
#        [ 75.99605 ],
#        [ 75.84447 ],
#        [ 74.10522 ],
#        [ 80.48763 ],
#        [ 82.615395],
#        [ 66.204765],
#        [ 58.64397 ],
#        [ 60.743164],
#        [ 65.400505],
#        [ 67.622765],
#        [ 72.796684],
#        [ 72.88205 ],
#        [ 65.666046],
#        [ 65.35825 ],
#        [ 60.366234],
#        [ 64.24173 ],
#        [ 61.054207],
#        [ 64.63558 ],
#        [ 68.721146],
#        [ 65.07865 ],
#        [ 56.894283],
#        [ 32.862556],
#        [ 19.615017],
#        [ 30.253712],
#        [ 41.159904],
#        [ 44.183487],
#        [ 45.70633 ],
#        [ 41.811844],
#        [ 41.08157 ],
#        [ 43.62376 ]], dtype=float32)

# %%
# shift train predictions for plotting
trainPredictPlot = np.empty_like(dataset)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict
# shift test predictions for plotting
testPredictPlot = np.empty_like(dataset)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = testPredict
# plot baseline and predictions
plt.plot(scaler.inverse_transform(dataset))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()

# %%
test_data
# Out:
#                  price
# Date
# 2021-03-31   65.410000
# 2021-04-30   64.806500
# 2021-05-31   68.534211
# 2021-06-30   73.164091
# 2021-07-31   75.165909
# 2021-08-31   70.747143
# 2021-09-30   74.488636
# 2021-10-31   83.538095
# 2021-11-30   81.050000
# 2021-12-31   74.170476
# 2022-01-31   86.505238
# 2022-02-28   97.129000
# 2022-03-31  117.245217
# 2022-04-30  104.575263
# 2022-05-31  113.337619
# 2022-06-30  122.710952
# 2022-07-31  111.925714
# 2022-08-31  100.446364
# 2022-09-30   89.764762
# 2022-10-31   93.331905
# 2022-11-30   91.415455
# 2022-12-31   80.924000
# 2023-01-31   82.501429
# 2023-02-28   82.608421

# %%
len(test_data)
# Out:
# 24

# %%
testPredict
# Out:
# array([[ 63.679043],
#        [ 66.880005],
#        [ 66.26429 ],
#        [ 70.0603  ],
#        [ 74.74664 ],
#        [ 76.76108 ],
#        [ 72.304634],
#        [ 76.080414],
#        [ 85.09125 ],
#        [ 82.63307 ],
#        [ 75.76033 ],
#        [ 88.00131 ],
#        [ 98.206604],
#        [116.45662 ],
#        [105.13639 ],
#        [113.03108 ],
#        [121.14663 ],
#        [111.77873 ],
#        [101.317955],
#        [ 91.16943 ],
#        [ 94.59982 ],
#        [ 92.761765],
#        [ 82.50816 ]], dtype=float32)

# %%
predited_data=pd.DataFrame(testPredict)

# %%
predited_data
# Out:
#              0
# 0    63.679043
# 1    66.880005
# 2    66.264290
# 3    70.060303
# 4    74.746643
# 5    76.761078
# 6    72.304634
# 7    76.080414
# 8    85.091248
# 9    82.633072
# 10   75.760330
# 11   88.001312
# 12   98.206604
# 13  116.456619
# 14  105.136391
# 15  113.031082
# 16  121.146629
# 17  111.778732
# 18  101.317955
# 19   91.169434
# 20   94.599823
# 21   92.761765
# 22   82.508163

# %%
predicted_data=[65.410000]
for i in predited_data[0]:
  predicted_data.append(i)
predicted_data
# Out:
# [65.41,
#  63.67904281616211,
#  66.8800048828125,
#  66.26428985595703,
#  70.060302734375,
#  74.74664306640625,
#  76.76107788085938,
#  72.30463409423828,
#  76.08041381835938,
#  85.09124755859375,
#  82.63307189941406,
#  75.76033020019531,
#  88.00131225585938,
#  98.20660400390625,
#  116.45661926269531,
#  105.13639068603516,
#  113.03108215332031,
#  121.1466293334961,
#  111.77873229980469,
#  101.31795501708984,
#  91.16943359375,
#  94.59982299804688,
#  92.76176452636719,
#  82.50816345214844]

# %%
Prediction=test_data.copy()

# %%
Prediction['Precited_price']=predicted_data

# %%
Prediction=Prediction.drop(columns=['price'])
Prediction
# Out:
#             Precited_price
# Date
# 2021-03-31       65.410000
# 2021-04-30       63.679043
# 2021-05-31       66.880005
# 2021-06-30       66.264290
# 2021-07-31       70.060303
# 2021-08-31       74.746643
# 2021-09-30       76.761078
# 2021-10-31       72.304634
# 2021-11-30       76.080414
# 2021-12-31       85.091248
# 2022-01-31       82.633072
# 2022-02-28       75.760330
# 2022-03-31       88.001312
# 2022-04-30       98.206604
# 2022-05-31      116.456619
# 2022-06-30      105.136391
# 2022-07-31      113.031082
# 2022-08-31      121.146629
# 2022-09-30      111.778732
# 2022-10-31      101.317955
# 2022-11-30       91.169434
# 2022-12-31       94.599823
# 2023-01-31       92.761765
# 2023-02-28       82.508163

# %%
plt.figure(figsize=(14,6))
plt.plot(train_data, label='Train')
plt.plot(test_data, label='Test')
plt.plot(Prediction, label='Prediction')
plt.legend(loc='best')
plt.show()

# %%
dataX, dataY = create_dataset(dataset, look_back)

# %%
model1 = Sequential()
model1.add(LSTM(4, input_shape=(1, look_back)))
model1.add(Dense(1))
model1.compile(loss='mean_squared_error', optimizer='adam')
model1.fit(dataX, dataY, epochs=100, batch_size=1, verbose=2)
# Out:
# Epoch 1/100
# 428/428 - 4s - loss: 0.0819 - 4s/epoch - 9ms/step
# Epoch 2/100
# 428/428 - 1s - loss: 0.0392 - 1s/epoch - 3ms/step
# Epoch 3/100
# 428/428 - 1s - loss: 0.0205 - 1s/epoch - 3ms/step
# Epoch 4/100
# 428/428 - 1s - loss: 0.0069 - 1s/epoch - 3ms/step
# Epoch 5/100
# 428/428 - 1s - loss: 0.0023 - 1s/epoch - 3ms/step
# Epoch 6/100
# 428/428 - 1s - loss: 0.0017 - 1s/epoch - 3ms/step
# Epoch 7/100
# 428/428 - 1s - loss: 0.0017 - 990ms/epoch - 2ms/step
# Epoch 8/100
# 428/428 - 1s - loss: 0.0017 - 971ms/epoch - 2ms/step
# Epoch 9/100
# 428/428 - 1s - loss: 0.0017 - 1s/epoch - 2ms/step
# Epoch 10/100
# 428/428 - 1s - loss: 0.0017 - 1s/epoch - 2ms/step
# Epoch 11/100
# 428/428 - 1s - loss: 0.0018 - 1s/epoch - 2ms/step
# Epoch 12/100
# 428/428 - 1s - loss: 0.0017 - 977ms/epoch - 2ms/step
# Epoch 13/100
# 428/428 - 1s - loss: 0.0017 - 966ms/epoch - 2ms/step
# Epoch 14/100
# 428/428 - 1s - loss: 0.0017 - 950ms/epoch - 2ms/step
# Epoch 15/100
# 428/428 - 1s - loss: 0.0017 - 1s/epoch - 2ms/step
# Epoch 16/100
# 428/428 - 1s - loss: 0.0017 - 1s/epoch - 3ms/step
# Epoch 17/100
# 428/428 - 1s - loss: 0.0018 - 1s/epoch - 3ms/step
# Epoch 18/100
# 428/428 - 1s - loss: 0.0018 - 1s/epoch - 3ms/step
# Epoch 19/100
# 428/428 - 1s - loss: 0.0017 - 1s/epoch - 3ms/step
# Epoch 20/100
# 428/428 - 1s - loss: 0.0017 - 1s/epoch - 3ms/step
# Epoch 21/100
# 428/428 - 1s - loss: 0.0018 - 1s/epoch - 3ms/step
# Epoch 22/100
# 428/428 - 1s - loss: 0.0017 - 1s/epoch - 3ms/step
# Epoch 23/100
# 428/428 - 1s - loss: 0.0017 - 1s/epoch - 3ms/step
# Epoch 24/100
# 428/428 - 1s - loss: 0.0018 - 1s/epoch - 3ms/step
# Epoch 25/100
# 428/428 - 1s - loss: 0.0017 - 1s/epoch - 3ms/step
# Epoch 26/100
# 428/428 - 1s - loss: 0.0017 - 1s/epoch - 3ms/step
# Epoch 27/100
# 428/428 - 1s - loss: 0.0017 - 1s/epoch - 3ms/step
# Epoch 28/100
# 428/428 - 1s - loss: 0.0018 - 967ms/epoch - 2ms/step
# Epoch 29/100
# 428/428 - 1s - loss: 0.0017 - 1s/epoch - 2ms/step
# Epoch 30/100
# 428/428 - 1s - loss: 0.0017 - 981ms/epoch - 2ms/step
# Epoch 31/100
# 428/428 - 1s - loss: 0.0017 - 928ms/epoch - 2ms/step
# Epoch 32/100
# 428/428 - 1s - loss: 0.0017 - 1s/epoch - 2ms/step
# Epoch 33/100
# 428/428 - 1s - loss: 0.0017 - 1s/epoch - 3ms/step
# Epoch 34/100
# 428/428 - 1s - loss: 0.0018 - 1s/epoch - 3ms/step
# Epoch 35/100
# 428/428 - 1s - loss: 0.0017 - 1s/epoch - 3ms/step
# Epoch 36/100
# 428/428 - 1s - loss: 0.0017 - 1s/epoch - 3ms/step
# Epoch 37/100
# 428/428 - 1s - loss: 0.0017 - 1s/epoch - 3ms/step
# Epoch 38/100
# 428/428 - 1s - loss: 0.0017 - 1s/epoch - 3ms/step
# Epoch 39/100
# 428/428 - 1s - loss: 0.0018 - 1s/epoch - 3ms/step
# Epoch 40/100
# 428/428 - 1s - loss: 0.0017 - 1s/epoch - 3ms/step
# Epoch 41/100
# 428/428 - 1s - loss: 0.0017 - 1s/epoch - 2ms/step
# Epoch 42/100
# 428/428 - 1s - loss: 0.0017 - 1s/epoch - 2ms/step
# Epoch 43/100
# 428/428 - 1s - loss: 0.0017 - 997ms/epoch - 2ms/step
# Epoch 44/100
# 428/428 - 1s - loss: 0.0017 - 969ms/epoch - 2ms/step
# Epoch 45/100
# 428/428 - 1s - loss: 0.0017 - 998ms/epoch - 2ms/step
# Epoch 46/100
# 428/428 - 1s - loss: 0.0017 - 1s/epoch - 3ms/step
# Epoch 47/100
# 428/428 - 1s - loss: 0.0018 - 1s/epoch - 3ms/step
# Epoch 48/100
# 428/428 - 1s - loss: 0.0017 - 1s/epoch - 3ms/step
# Epoch 49/100
# 428/428 - 2s - loss: 0.0018 - 2s/epoch - 4ms/step
# Epoch 50/100
# 428/428 - 2s - loss: 0.0017 - 2s/epoch - 4ms/step
# Epoch 51/100
# 428/428 - 1s - loss: 0.0017 - 1s/epoch - 3ms/step
# Epoch 52/100
# 428/428 - 2s - loss: 0.0017 - 2s/epoch - 4ms/step
# Epoch 53/100
# 428/428 - 1s - loss: 0.0017 - 1s/epoch - 3ms/step
# Epoch 54/100
# 428/428 - 1s - loss: 0.0017 - 1s/epoch - 3ms/step
# Epoch 55/100
# 428/428 - 1s - loss: 0.0017 - 1s/epoch - 2ms/step
# Epoch 56/100
# 428/428 - 1s - loss: 0.0017 - 947ms/epoch - 2ms/step
# Epoch 57/100
# 428/428 - 1s - loss: 0.0017 - 960ms/epoch - 2ms/step
# Epoch 58/100
# 428/428 - 1s - loss: 0.0017 - 955ms/epoch - 2ms/step
# Epoch 59/100
# 428/428 - 1s - loss: 0.0017 - 905ms/epoch - 2ms/step
# Epoch 60/100
# 428/428 - 1s - loss: 0.0017 - 883ms/epoch - 2ms/step
# Epoch 61/100
# 428/428 - 1s - loss: 0.0017 - 988ms/epoch - 2ms/step
# Epoch 62/100
# 428/428 - 1s - loss: 0.0017 - 1s/epoch - 3ms/step
# Epoch 63/100
# 428/428 - 1s - loss: 0.0017 - 1s/epoch - 3ms/step
# Epoch 64/100
# 428/428 - 1s - loss: 0.0018 - 1s/epoch - 3ms/step
# Epoch 65/100
# 428/428 - 1s - loss: 0.0017 - 1s/epoch - 3ms/step
# Epoch 66/100
# 428/428 - 1s - loss: 0.0017 - 1s/epoch - 3ms/step
# Epoch 67/100
# 428/428 - 1s - loss: 0.0018 - 1s/epoch - 2ms/step
# Epoch 68/100
# 428/428 - 1s - loss: 0.0017 - 998ms/epoch - 2ms/step
# Epoch 69/100
# 428/428 - 1s - loss: 0.0017 - 912ms/epoch - 2ms/step
# Epoch 70/100
# 428/428 - 1s - loss: 0.0017 - 942ms/epoch - 2ms/step
# Epoch 71/100
# 428/428 - 1s - loss: 0.0017 - 996ms/epoch - 2ms/step
# Epoch 72/100
# 428/428 - 1s - loss: 0.0017 - 987ms/epoch - 2ms/step
# Epoch 73/100
# 428/428 - 1s - loss: 0.0018 - 1s/epoch - 3ms/step
# Epoch 74/100
# 428/428 - 1s - loss: 0.0018 - 1s/epoch - 3ms/step
# Epoch 75/100
# 428/428 - 1s - loss: 0.0018 - 1s/epoch - 3ms/step
# Epoch 76/100
# 428/428 - 1s - loss: 0.0018 - 1s/epoch - 3ms/step
# Epoch 77/100
# 428/428 - 1s - loss: 0.0017 - 1s/epoch - 3ms/step
# Epoch 78/100
# 428/428 - 1s - loss: 0.0017 - 1s/epoch - 3ms/step
# Epoch 79/100
# 428/428 - 1s - loss: 0.0017 - 1s/epoch - 3ms/step
# Epoch 80/100
# 428/428 - 1s - loss: 0.0017 - 1s/epoch - 3ms/step
# Epoch 81/100
# 428/428 - 1s - loss: 0.0017 - 1s/epoch - 3ms/step
# Epoch 82/100
# 428/428 - 1s - loss: 0.0017 - 975ms/epoch - 2ms/step
# Epoch 83/100
# 428/428 - 1s - loss: 0.0018 - 1s/epoch - 2ms/step
# Epoch 84/100
# 428/428 - 1s - loss: 0.0017 - 974ms/epoch - 2ms/step
# Epoch 85/100
# 428/428 - 1s - loss: 0.0017 - 937ms/epoch - 2ms/step
# Epoch 86/100
# 428/428 - 1s - loss: 0.0017 - 1s/epoch - 3ms/step
# Epoch 87/100
# 428/428 - 1s - loss: 0.0018 - 1s/epoch - 3ms/step
# Epoch 88/100
# 428/428 - 1s - loss: 0.0017 - 1s/epoch - 3ms/step
# Epoch 89/100
# 428/428 - 1s - loss: 0.0017 - 1s/epoch - 3ms/step
# Epoch 90/100
# 428/428 - 1s - loss: 0.0017 - 1s/epoch - 3ms/step
# Epoch 91/100
# 428/428 - 1s - loss: 0.0017 - 1s/epoch - 3ms/step
# Epoch 92/100
# 428/428 - 1s - loss: 0.0018 - 1s/epoch - 3ms/step
# Epoch 93/100
# 428/428 - 1s - loss: 0.0017 - 1s/epoch - 3ms/step
# Epoch 94/100
# 428/428 - 1s - loss: 0.0017 - 1s/epoch - 3ms/step
# Epoch 95/100
# 428/428 - 1s - loss: 0.0017 - 1s/epoch - 3ms/step
# Epoch 96/100
# 428/428 - 1s - loss: 0.0017 - 1s/epoch - 3ms/step
# Epoch 97/100
# 428/428 - 1s - loss: 0.0017 - 1s/epoch - 2ms/step
# Epoch 98/100
# 428/428 - 1s - loss: 0.0017 - 1s/epoch - 2ms/step
# Epoch 99/100
# 428/428 - 1s - loss: 0.0018 - 937ms/epoch - 2ms/step
# Epoch 100/100
# 428/428 - 1s - loss: 0.0018 - 1s/epoch - 3ms/step

# %%
dataset1 = dataset.reshape((-1))

def predict(num_prediction, model):
    prediction_list = dataset[-look_back:]

    for _ in range(num_prediction):
        x = prediction_list[-look_back:]
        x = x.reshape((1, look_back, 1))
        out = model.predict(x)[0][0]
        prediction_list = np.append(prediction_list, out)
    prediction_list = prediction_list[look_back-1:]

    return prediction_list

def predict_dates(num_prediction):
    last_date = df2.index.values[-1]
    prediction_dates = pd.date_range(last_date, periods=num_prediction+1,freq='M').tolist()
    return prediction_dates

# %%
num_prediction = 30
forecast = predict(num_prediction, model1)
forecast_dates = predict_dates(num_prediction)
# Out:
# 1/1 [==============================] - 1s 684ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 34ms/step

# %%
forecast=forecast.reshape(-1,1)
forecast = scaler.inverse_transform(forecast)
forecast
# Out:
# array([[ 82.60842105],
#        [ 84.76588954],
#        [ 86.89394755],
#        [ 88.97210002],
#        [ 90.98071581],
#        [ 92.90193647],
#        [ 94.72053322],
#        [ 96.42441241],
#        [ 98.00503303],
#        [ 99.45747998],
#        [100.78025895],
#        [101.97493749],
#        [103.04568356],
#        [103.99865753],
#        [104.84147012],
#        [105.58264767],
#        [106.23117071],
#        [106.79610031],
#        [107.28629979],
#        [107.71020026],
#        [108.07568348],
#        [108.39000857],
#        [108.65973145],
#        [108.89072681],
#        [109.08822473],
#        [109.25686196],
#        [109.40067461],
#        [109.52319335],
#        [109.62748004],
#        [109.71617171],
#        [109.79156842]])

# %%
forecast_dates=pd.to_datetime(forecast_dates)
forecast_dates
# Out:
# DatetimeIndex(['2023-02-28', '2023-03-31', '2023-04-30', '2023-05-31',
#                '2023-06-30', '2023-07-31', '2023-08-31', '2023-09-30',
#                '2023-10-31', '2023-11-30', '2023-12-31', '2024-01-31',
#                '2024-02-29', '2024-03-31', '2024-04-30', '2024-05-31',
#                '2024-06-30', '2024-07-31', '2024-08-31', '2024-09-30',
#                '2024-10-31', '2024-11-30', '2024-12-31', '2025-01-31',
#                '2025-02-28', '2025-03-31', '2025-04-30', '2025-05-31',
#                '2025-06-30', '2025-07-31', '2025-08-31'],
#               dtype='datetime64[ns]', freq=None)

# %%
forecasted_data_final=pd.DataFrame()

# %%
forecasted_data_final['Date']=forecast_dates
forecasted_data_final['Price']=forecast
forecasted_data_final.drop(index=0,inplace=True)
forecasted_data_final
# Out:
#          Date       Price
# 1  2023-03-31   84.765890
# 2  2023-04-30   86.893948
# 3  2023-05-31   88.972100
# 4  2023-06-30   90.980716
# 5  2023-07-31   92.901936
# 6  2023-08-31   94.720533
# 7  2023-09-30   96.424412
# 8  2023-10-31   98.005033
# 9  2023-11-30   99.457480
# 10 2023-12-31  100.780259
# 11 2024-01-31  101.974937
# 12 2024-02-29  103.045684
# 13 2024-03-31  103.998658
# 14 2024-04-30  104.841470
# 15 2024-05-31  105.582648
# 16 2024-06-30  106.231171
# 17 2024-07-31  106.796100
# 18 2024-08-31  107.286300
# 19 2024-09-30  107.710200
# 20 2024-10-31  108.075683
# 21 2024-11-30  108.390009
# 22 2024-12-31  108.659731
# 23 2025-01-31  108.890727
# 24 2025-02-28  109.088225
# 25 2025-03-31  109.256862
# 26 2025-04-30  109.400675
# 27 2025-05-31  109.523193
# 28 2025-06-30  109.627480
# 29 2025-07-31  109.716172
# 30 2025-08-31  109.791568

# %%
forecasted_data_final.set_index('Date', inplace=True)
forecasted_data_final
# Out:
#                  Price
# Date
# 2023-03-31   84.765890
# 2023-04-30   86.893948
# 2023-05-31   88.972100
# 2023-06-30   90.980716
# 2023-07-31   92.901936
# 2023-08-31   94.720533
# 2023-09-30   96.424412
# 2023-10-31   98.005033
# 2023-11-30   99.457480
# 2023-12-31  100.780259
# 2024-01-31  101.974937
# 2024-02-29  103.045684
# 2024-03-31  103.998658
# 2024-04-30  104.841470
# 2024-05-31  105.582648
# 2024-06-30  106.231171
# 2024-07-31  106.796100
# 2024-08-31  107.286300
# 2024-09-30  107.710200
# 2024-10-31  108.075683
# 2024-11-30  108.390009
# 2024-12-31  108.659731
# 2025-01-31  108.890727
# 2025-02-28  109.088225
# 2025-03-31  109.256862
# 2025-04-30  109.400675
# 2025-05-31  109.523193
# 2025-06-30  109.627480
# 2025-07-31  109.716172
# 2025-08-31  109.791568

# %%
plt.figure(figsize=(14,6))
plt.plot(df2, label='Original')
plt.plot(forecasted_data_final, label='Forecast')
#plt.plot(Prediction, label='Prediction')
plt.legend(loc='best')
plt.show()

# %%
import joblib
joblib.dump(model1, 'model1.pkl')
# Out:
# ['model1.pkl']

# %%
import pickle
pickle.dump(model1, open('forecast_model.pkl','wb'))
